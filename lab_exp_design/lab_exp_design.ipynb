# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Mallory"
ca1_name = "Irene"
ca2_name = "Amelie"
ca3_name = ""

# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "Yunhan"
partner1_netid = "yunhanc3"
partner1_inYourGroupLastWeek = "no"

partner2_name = "Andrew"
partner2_netid = "as251"
partner2_inYourGroupLastWeek = "no"

partner3_name = "Yifan"
partner3_netid = "yifan57"
partner3_inYourGroupLastWeek = "no"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the **"Hello Dataset"**.  Before lab, you completed this survey along with the entire course.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# Are you male or female?

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-fa24.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df` -- and **don't forget to import pandas**! :)

# %%
import pandas as pd

df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-fa24.csv")

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **`__in a text editor__`** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Lab',
#  'When flipping a coin, heads or tails?',
#  'Is this your first year at UIUC?',
#  'Is your favorite ice cream flavor chocolate or vanilla?',
#  'Do you like morning or night? ',
#  'Do you prefer even or odd numbers?',
#  'Do you have a pet?',
#  'Do you prefer summer or winter?',
#  'Are you a business major?',
#  'Do you prefer Movies or TV shows?',
#  'Do you prefer pizza or hamburgers?',
#  'Are you male or female?',
#  'Do you prefer the color Blue or Red?',
#  'Do you like Taylor Swifts music?',
#  'Do you prefer sweet or salty food?',
#  'Do you eat breakfast in the mornings?',
#  'Ice cream or cake? ',
#  'Are you an upperclassman or an underclassman?',
#  'As you walk in from the back, do you prefer to sit on the left or right side of lecture?',
#  'Is the day of the month of your birthday an odd or even number?',
#  'Do you speak a second language?',
#  'Do you prefer cats or dogs?',
#  'Are you a morning person or a night person?',
#  'Do you enjoy reading?',
#  'Do you prefer milk chocolate or dark chocolate?',
#  'Do you prefer Italian or Mexican food?',
#  'Do you prefer sugar cookies or chocolate chip cookies?',
#  'Can you speak a second language fluently?',
#  'Do you prefer Math or English?',
#  'Do you like apples or bananas?',
#  'Waffles or pancakes?',
#  'Do you prefer day or night?',
#  'Do you prefer lecture halls or small classes? ',
#  'Are you in-state or out of state?',
#  'Do you typically shower in the morning or at night?',
#  'Does money buy happiness?',
#  'Do you prefer to party or stay in?',
#  'McDonalds or Burger King?',
#  'Do you prefer sweet or savory food?',
#  'What month is your birthday?',
#  'Do you drink a cup of coffee every morning?',
#  'Do you drink coffee?',
#  'Do you use a Mac or Windows Laptop?',
#  'Do you prefer brownies or cookies?',
#  'Google Docs or Microsoft Word?',
#  'Do you like horror movies?',
#  'Do you have programming experience?',
#  'Do you like pizza or pasta?',
#  'Do you wear glasses?',
#  'Do you like your dorm?',
#  'Fall or spring season?',
#  'Do you prefer pink or blue?',
#  'Are you from the Chicagoland area?',
#  'Does your NetID end with an even or odd number?',
#  'Are you wearing something on your wrist currently?',
#  'Is it called Futbol or Soccer?',
#  'Do you use corrective lenses (contacts/glasses)?',
#  'Do you prefer Apple Music or Spotify?',
#  'Do you have exactly one sibling?',
#  'Are you taking any other computer science classes?',
#  'In the DISCOVERY lecture, do you sit in the front 50% or back 50%?',
#  'Do you sit on the left or right side in lecture?',
#  'Pick a random number 1-10. is the number you picked odd or even?',
#  'Are you from Chicago?',
#  'Pick a number: One or Two.',
#  'Do you prefer to study alone or in groups?',
#  'Do you prefer Apple or Google maps?',
#  'Do you prefer apple juice or orange juice?',
#  'Do you prefer basketball or football?',
#  'Do you prefer the beach or mountains?',
#  'Is your UIN an even number?',
#  'Were you born before or after 2006?',
#  "Would you sit behind the driver or the passenger seat when you're at the back seat in a car?",
#  'Did you come from a big or a small high school?',
#  "Are you shorter or taller than 5'7 (170cm)?",
#  'Do you prefer breakfast or dinner?',
#  'Do you prefer go to school by bus or by walking?',
#  'Did the chicken or the egg come first?',
#  'Do you prefer Coca Cola or Pepsi?',
#  'Do you prefer Coca-Cola or Sprite?',
#  'Do you prefer coffee or tea?',
#  'Dawn or Dusk?',
#  'Would you rather drown or burn to death?',
#  'Are you an extrovert or introvert?',
#  'Do you prefer gold or silver jewelry?',
#  'Do you prefer group projects or solo assignments?',
#  'Do you prefer a hot location vacation or a cold vacation location?',
#  'Do you prefer hotdogs or hamburgers?',
#  'Are you taking stat107 for your major or not?',
#  'Who is a better poet?',
#  "Do you prefer 'light mode' or 'dark mode' on your technological devices?",
#  'Do you have long hair or short hair?',
#  'Do you prefer morning or afternoon classes?',
#  'Do you prefer indoor or outdoor activities?',
#  'Do you prefer Pizza or Cheeseburgers?',
#  'Do you like Messi or Ronaldo?',
#  'Do you prefer running or walking?',
#  'What soccer team is better?',
#  'Do you prefer strawberries or blueberries?',
#  'Do you live in student housing (i.e. dorms) or private housing (i.e. apartments)?',
#  'Do you like the warm or cold weather better?',
#  'Would you rather your head be the size of a watermelon or an orange?',
#  'Do you prefer wings or burgers?',
#  'Do you prefer Playstation or Xbox?',
#  'Y or N?',
#  'Do you like the color yellow?',
#  'Do you like ranch?',
#  'Were you born in the United States?',
#  'Do you consider yourself an international student?',
#  'Have you ever been outside of United States?',
#  'Have you ever had COVID-19?',
#  'Do you like chocolate?',
#  'Do you like spicy food?',
#  'What\'s the color of "the dress"? (See it here: https://en.wikipedia.org/wiki/The_dress)',
#  'Are you taking 16 or more credit hours this semester?',
#  'Do you have siblings?',
#  'Did you play sports in high school? ',
#  'Does pineapple belong on pizza?',
#  'Is purple your favorite color? ',
#  'Do you like bananas?',
#  'Do you like Champaign?',
#  'Do you like rainy weather?',
#  'Does the First Letter of your last name Start with a Letter A-L Including L? ',
#  'Do you like Durian?',
#  'Pick between TRUE or FALSE.',
#  'Do you prefer watching basketball or football games?',
#  'Do you prefer caramel or sprinkle toppings on your ice cream?',
#  'Can you swim? ',
#  'Would you rather be to see the future or change the past?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a night?',
#  'How many siblings do you have?',
#  'Pick a number between 1 and 10. ',
#  'What is your shoe size (US size)?',
#  'How many cups (8 oz.) of water do you drink a day?',
#  'What number do you consider as an unlucky number?',
#  'How many people is the ideal number of people at a party?',
#  'What is your phone battery percentage currently at?',
#  'Besides the US, what country would you like to live in?',
#  'What is your favorite color?',
#  'Favorite way to spend your free time?',
#  'What genre of music do you like the most?',
#  'If you were an animal, which would you be? / What is your spirit animal?',
#  'What do you think is the hardest major at UIUC?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'What is your favorite game to play (either video game or IRL)?',
#  'Where is your dream vacation spot?']

# %% [markdown]
# ## Record the Variable for Your Question
#
# In the cell below, record your binary question's column name as a **string** variable named `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column = "Are you male or female?"
analysis_column
# Out:
# 'Are you male or female?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df' in vars()), "You do not have a DataFrame called `df`."
assert(len(df) >= 1053), "You have not loaded the correct Hello Dataset."
assert(analysis_column in df), "Make certain your analysis_column string is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you first want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the outer set for `df`, and the inner set for the column name.
# - Because we've already loaded your question into `analysis_column`, you won't need the quotation marks this time.
# - You can find this syntax under the "Subset Variables (Columns)" on your Pandas cheat sheet!
#
# With the `analysis_column` variable from above, use Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[ [analysis_column]]
# Out:
#      Are you male or female?
# 0                     Female
# 1                       Male
# 2                     Female
# 3                       Male
# 4                     Female
# ...                      ...
# 1065                    Male
# 1066                  Female
# 1067                    Male
# 1068                    Male
# 1069                    Male
#
# [1070 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df[analysis_column] == "Female"]
df1
# Out:
#              Name       Lab When flipping a coin, heads or tails?  \
# 0     Prof. Karle  AL1, AL2                                 Heads
# 2        Angelina       Y13                                 Tails
# 4          Sneha        Y17                                 Tails
# 8            Eman       Y11                                 Heads
# 9          Amanda       Y23                                 Heads
# ...           ...       ...                                   ...
# 1057     CA Bella       Y34                                 Heads
# 1058     Isabella       Y25                                 Heads
# 1059      CA Lara  Y19, Y20                                 Tails
# 1062       Eunice       Y28                                 Heads
# 1066     CA Elise  Y11, Y33                                 Heads
#
#      Is this your first year at UIUC?  \
# 0                      Not First Year
# 2                  First Year at UIUC
# 4                  First Year at UIUC
# 8                  First Year at UIUC
# 9                  First Year at UIUC
# ...                               ...
# 1057                   Not First Year
# 1058               First Year at UIUC
# 1059                   Not First Year
# 1062               First Year at UIUC
# 1066                   Not First Year
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                             Chocolate
# 2                                               Vanilla
# 4                                               Vanilla
# 8                                             Chocolate
# 9                                               Vanilla
# ...                                                 ...
# 1057                                          Chocolate
# 1058                                            Vanilla
# 1059                                          Chocolate
# 1062                                          Chocolate
# 1066                                            Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 0                             Night                               Even
# 2                           Morning                               Even
# 4                             Night                               Even
# 8                           Morning                               Even
# 9                             Night                               Even
# ...                             ...                                ...
# 1057                        Morning                               Even
# 1058                          Night                                Odd
# 1059                          Night                               Even
# 1062                          Night                               Even
# 1066                          Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                    No                          Summer
# 2                   Yes                          Summer
# 4                    No                          Summer
# 8                    No                          Summer
# 9                   Yes                          Summer
# ...                 ...                             ...
# 1057                Yes                          Summer
# 1058                Yes                          Summer
# 1059                 No                          Summer
# 1062                 No                          Summer
# 1066                Yes                          Summer
#
#      Are you a business major?  ...  \
# 0                           No  ...
# 2                           No  ...
# 4                          Yes  ...
# 8                           No  ...
# 9                          Yes  ...
# ...                        ...  ...
# 1057                        No  ...
# 1058                       Yes  ...
# 1059                        No  ...
# 1062                       Yes  ...
# 1066                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 0                                          The Maldives
# 2                                            Hong Kong
# 4                                                Canada
# 8                                                   UAE
# 9                                                   NaN
# ...                                                 ...
# 1057                                            sweeden
# 1058                                          Australia
# 1059                                             Canada
# 1062                                        south korea
# 1066                                            England
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 0                            pink                         water skiing!
# 2                            Pink                        Watching shows
# 4                           Green                 Reading or crocheting
# 8                             Red                Hang out with friends
# 9                           Green                     Watching TV shows
# ...                           ...                                   ...
# 1057                       purple                               outside
# 1058                         Blue                       Watching shows.
# 1059                        beige                               reading
# 1062                         blue                         playing piano
# 1066                         Pink                          With friends
#
#      What genre of music do you like the most?  \
# 0                                          pop
# 2                                          r&b
# 4                                     Pop Rock
# 8                                          R&B
# 9                                          Pop
# ...                                        ...
# 1057                                       pop
# 1058                                       Pop
# 1059                                Riot grrrl
# 1062                                      kpop
# 1066                                 Indie pop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 sloth
# 2                                                 Tiger
# 4                                               Penguin
# 8                                               Unicorn
# 9                                               Dolphin
# ...                                                 ...
# 1057                                          butterfly
# 1058                                            Raccoon
# 1059                                        sea anemone
# 1062                                              sloth
# 1066                                               Wolf
#
#      What do you think is the hardest major at UIUC?  \
# 0                                   Computer Science
# 2                             Aerospace engineering
# 4                                   Computer Science
# 8                                            Physics
# 9                                        Engineering
# ...                                              ...
# 1057                            chemical engineering
# 1058                            Chemical Engineering
# 1059                                         Physics
# 1062                                     engineering
# 1066                                            Eecs
#
#      Who is your favorite music artist?  \
# 0                          Taylor Swift
# 2                         Ashley Alisha
# 4                       Imagine Dragons
# 8                                   SZA
# 9                                   NaN
# ...                                 ...
# 1057                       taylor swift
# 1058                       Lana Del Rey
# 1059                            Slant 6
# 1062                                IVE
# 1066                       Taylor swift
#
#      What's your favorite social media app?  \
# 0                                 Instagram
# 2                                     Insta
# 4                                 Instagram
# 8                                 Instagram
# 9                                 Instagram
# ...                                     ...
# 1057                              pinterest
# 1058                                 Tiktok
# 1059                                 Reddit
# 1062                              instagram
# 1066                              Pinterest
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                            volleyball
# 2                                                   NaN
# 4                                            Beat Saber
# 8                                                  Sims
# 9                                                   NaN
# ...                                                 ...
# 1057                             pretty pretty princess
# 1058                                       21 questions
# 1059                                           Oxenfree
# 1062                                            genshin
# 1066                                           Pinochle
#
#      Where is your dream vacation spot?
# 0                          The Maldives
# 2                       Southern France
# 4                                 Italy
# 8                               Greece
# 9                                 Italy
# ...                                 ...
# 1057                             vienna
# 1058                            Iceland
# 1059                              Japan
# 1062                              Italy
# 1066                              Kenya
#
# [462 rows x 150 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df[analysis_column] == "Male"]
df2
# Out:
#             Name       Lab When flipping a coin, heads or tails?  \
# 1     Prof. Wade  AL1, AL2                                 Tails
# 3       TA Tyler       Y07                                 Tails
# 5           Gage       Y10                                 Heads
# 6          Mark        Y04                                 Heads
# 7          Jaden       Y34                                 Heads
# ...          ...       ...                                   ...
# 1064      Wesley       Y02                                 Tails
# 1065    Man Geun       Y04                                 Heads
# 1067     Chinmay       Y11                                 Heads
# 1068       Bowen       Y25                                 Heads
# 1069    kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 1                      Not First Year
# 3                      Not First Year
# 5                  First Year at UIUC
# 6                      Not First Year
# 7                  First Year at UIUC
# ...                               ...
# 1064                   Not First Year
# 1065                   Not First Year
# 1067               First Year at UIUC
# 1068               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1                                               Vanilla
# 3                                             Chocolate
# 5                                               Vanilla
# 6                                             Chocolate
# 7                                             Chocolate
# ...                                                 ...
# 1064                                            Vanilla
# 1065                                            Vanilla
# 1067                                          Chocolate
# 1068                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1                             Night                                Odd
# 3                             Night                               Even
# 5                             Night                               Even
# 6                           Morning                               Even
# 7                           Morning                               Even
# ...                             ...                                ...
# 1064                          Night                               Even
# 1065                          Night                               Even
# 1067                          Night                               Even
# 1068                          Night                                Odd
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1                   Yes                          Winter
# 3                    No                          Winter
# 5                   Yes                          Winter
# 6                    No                          Winter
# 7                    No                          Summer
# ...                 ...                             ...
# 1064                 No                          Summer
# 1065                 No                          Winter
# 1067                 No                          Summer
# 1068                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 1                           No  ...
# 3                           No  ...
# 5                           No  ...
# 6                           No  ...
# 7                           No  ...
# ...                        ...  ...
# 1064                        No  ...
# 1065                        No  ...
# 1067                        No  ...
# 1068                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 1                                                Sweden
# 3                                                Canada
# 5                                               Canada
# 6                                                Sweden
# 7                                                 japan
# ...                                                 ...
# 1064                                              japan
# 1065                                              Korea
# 1067                                              India
# 1068                                              China
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 1                          Purple                           Programming
# 3                          Orange                              Terraria
# 5                           Green                   Fishing or Hunting
# 6                           green                               reading
# 7                            blue                     talk with friends
# ...                           ...                                   ...
# 1064                         blue                                 sleep
# 1065                         Blue                           Playstation
# 1067                         Blue                                 Music
# 1068                       Purple                                 Films
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 1                                          Pop
# 3                                     Pop rock
# 5                                 Grunge Rock
# 6                                          pop
# 7                                          pop
# ...                                        ...
# 1064                                       pop
# 1065                                       Pop
# 1067                                       Rap
# 1068                                      Rocj
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1                                                   Fox
# 3                                                   Bee
# 5                                                 Bear
# 6                                                 Zebra
# 7                                                   dog
# ...                                                 ...
# 1064                                         dog/ camel
# 1065                                                Dog
# 1067                                                Dog
# 1068                                              Puppy
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 1                                   Computer Science
# 3                               Chemical Engineering
# 5                                              Math
# 6                               computer engineering
# 7                                                 CS
# ...                                              ...
# 1064                                         english
# 1065                                              CS
# 1067                                Computer Science
# 1068                                     Engineering
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 1                          Taylor Swift
# 3                            Billy Joel
# 5                            Jim Croce
# 6                                   sza
# 7                                 keshi
# ...                                 ...
# 1064                         juice wrld
# 1065                                 IU
# 1067                       Travis Scott
# 1068                         Kanye West
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 1                                   YouTube
# 3                                    Reddit
# 5                                    Tiktok
# 6                                 instagram
# 7                                    wechat
# ...                                     ...
# 1064                                youtube
# 1065                              Instagram
# 1067                              Instagram
# 1068                                    ins
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1                                              Factorio
# 3                                              Terraria
# 5                                           Titanfall 2
# 6                                              Fortnite
# 7                                                   LOL
# ...                                                 ...
# 1064                                        brawl stars
# 1065                                              NBA2k
# 1067                                             Tennis
# 1068                                     Stardew Valley
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 1                                Acadia
# 3                          My apartment
# 5                 Denali National Park
# 6                             australia
# 7                                 china
# ...                                 ...
# 1064                              japan
# 1065                             Cancun
# 1067                             Monaco
# 1068                              Tokyo
# 1069                            iceland
#
# [605 rows x 150 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %% [markdown]
# 43% of people chose the "Female" option and 56% of people chose the "Male" option.

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# This answer was not too surprising. From going to lecture, I know that the class is near 50/50 male-female, but using contextual knowledge we know that there are usually more males than females in STEM classes, so it makes sense that the percentage of people who selected the "Male" option is greater than the percentage of people who selected the "Female" option.

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# No, Female is 7 percentage points less from 50 and Male is 4 percentage points greater than 50. These are significantly far away from 50/50 and there are likely results that are at an even closer split, such as 49/51.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# **Randomly** select half (50%) of the participants from our original `df` to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can ask your CAs, TAs, or use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac=0.5)
treatment
# Out:
#         Name  Lab When flipping a coin, heads or tails?  \
# 479     Luke  Y20                                 Heads
# 676  Michael  Y36                                 Tails
# 606   Camden  Y28                                 Heads
# 653    Henry  Y02                                 Tails
# 967    Rosie  Y15                                 Heads
# ..       ...  ...                                   ...
# 326      Max  Y19                                 Heads
# 338     Yash  Y11                                 Heads
# 155    Dilan  Y26                                 Heads
# 891   Samuel  Y35                                 Heads
# 399    Ammar  Y36                                 Tails
#
#     Is this your first year at UIUC?  \
# 479               First Year at UIUC
# 676               First Year at UIUC
# 606               First Year at UIUC
# 653               First Year at UIUC
# 967               First Year at UIUC
# ..                               ...
# 326               First Year at UIUC
# 338               First Year at UIUC
# 155               First Year at UIUC
# 891                   Not First Year
# 399               First Year at UIUC
#
#     Is your favorite ice cream flavor chocolate or vanilla?  \
# 479                                            Vanilla
# 676                                            Vanilla
# 606                                          Chocolate
# 653                                            Vanilla
# 967                                          Chocolate
# ..                                                 ...
# 326                                          Chocolate
# 338                                            Vanilla
# 155                                            Vanilla
# 891                                            Vanilla
# 399                                            Vanilla
#
#     Do you like morning or night?  Do you prefer even or odd numbers?  \
# 479                          Night                               Even
# 676                          Night                               Even
# 606                          Night                               Even
# 653                        Morning                               Even
# 967                          Night                               Even
# ..                             ...                                ...
# 326                          Night                               Even
# 338                        Morning                               Even
# 155                          Night                               Even
# 891                        Morning                               Even
# 399                          Night                               Even
#
#     Do you have a pet? Do you prefer summer or winter?  \
# 479                 No                          Winter
# 676                 No                          Summer
# 606                Yes                          Summer
# 653                Yes                          Winter
# 967                 No                          Winter
# ..                 ...                             ...
# 326                Yes                          Summer
# 338                 No                          Summer
# 155                 No                          Winter
# 891                 No                          Summer
# 399                 No                          Winter
#
#     Are you a business major?  ...  \
# 479                        No  ...
# 676                       Yes  ...
# 606                       Yes  ...
# 653                        No  ...
# 967                        No  ...
# ..                        ...  ...
# 326                        No  ...
# 338                        No  ...
# 155                        No  ...
# 891                        No  ...
# 399                       Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 479                                              CHINA
# 676                                               utah
# 606                                              Italy
# 653                                              Swiss
# 967                                              China
# ..                                                 ...
# 326                                             Canada
# 338                                                UAE
# 155                                             Canada
# 891                                                 UK
# 399                                          Australia
#
#     What is your favorite color? Favorite way to spend your free time?  \
# 479                         cyan                           play tetrio
# 676                       purple                               golfign
# 606                         Blue                 Hanging with friends
# 653                         blue                               Nature
# 967                         Blue                   Playing video games
# ..                           ...                                   ...
# 326                        Green              Hanging out with friends
# 338                         Blue                       Watching sports
# 155                        White                                 Sleep
# 891                         Blue                    Reading and gaming
# 399                        green                                sports
#
#     What genre of music do you like the most?  \
# 479                             Lock in music
# 676                              classic rock
# 606                                       Rap
# 653                                       pop
# 967                                      Kpop
# ..                                        ...
# 326                                       Pop
# 338                              Classic rock
# 155                                      Jazz
# 891                                       Pop
# 399                                     R & B
#
#     If you were an animal, which would you be? / What is your spirit animal?  \
# 479                                                cat
# 676                                                dog
# 606                                              Eagle
# 653                                                fox
# 967                                              A dog
# ..                                                 ...
# 326                                              Shark
# 338                                           Elephant
# 155                                           Capybara
# 891                                             Falcon
# 399                                            Cheetah
#
#     What do you think is the hardest major at UIUC?  \
# 479                                         cs+math
# 676                                     engineering
# 606                                     Engineering
# 653                                            Math
# 967                                              cs
# ..                                              ...
# 326                                       Chemistry
# 338                                         Physics
# 155                          Electrical engineering
# 891                                Computer Science
# 399                                Computer Science
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 479                                NaN                                DISCORD
# 676                              drake                                 tiktok
# 606                       Travis Scott                              Instagram
# 653                     Taylor  Swift                                Telegram
# 967                              aespa                              Instagram
# ..                                 ...                                    ...
# 326                           Coldplay                              Instagram
# 338                                NaN                                Youtube
# 155                  Tatsuro Yamashita                              Instagram
# 891                        The Weekend                              Instagram
# 399                              Drake                               snapchat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 479  TETRIO, INSTALL TETRIO RIGHT NOW COME TO THE C...
# 676                                               golf
# 606                                        Volleyball
# 653                                              GTA5
# 967                                     Honor of kings
# ..                                                 ...
# 326                                         Basketball
# 338                                             Tennis
# 155                                              Smash
# 891                                       Ready or Not
# 399                                              poker
#
#     Where is your dream vacation spot?
# 479                                Idk
# 676                           maldives
# 606                             Europe
# 653                              swiss
# 967                             Hawaii
# ..                                 ...
# 326                          Australia
# 338                              Egypt
# 155                              Swiss
# 891                              Beach
# 399                       South Africa
#
# [535 rows x 150 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also randomly select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac=0.5)
control
# Out:
#           Name  Lab When flipping a coin, heads or tails?  \
# 151    Dhanush  Y06                                 Heads
# 19       Brady  Y16                                 Heads
# 662      Aaron  Y25                                 Tails
# 884       Esha  Y28                                 Heads
# 422     Yujian  Y12                                 Heads
# ...        ...  ...                                   ...
# 983        Mia  Y31                                 Heads
# 420   Prajeeta  Y19                                 Heads
# 1028     Lizzy  Y18                                 Heads
# 150     Andrew  Y01                                 Heads
# 29       Jiali  Y30                                 Heads
#
#      Is this your first year at UIUC?  \
# 151                    Not First Year
# 19                 First Year at UIUC
# 662                    Not First Year
# 884                First Year at UIUC
# 422                    Not First Year
# ...                               ...
# 983                First Year at UIUC
# 420                First Year at UIUC
# 1028               First Year at UIUC
# 150                    Not First Year
# 29                 First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 151                                             Vanilla
# 19                                              Vanilla
# 662                                             Vanilla
# 884                                             Vanilla
# 422                                             Vanilla
# ...                                                 ...
# 983                                           Chocolate
# 420                                             Vanilla
# 1028                                          Chocolate
# 150                                           Chocolate
# 29                                              Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 151                         Morning                               Even
# 19                          Morning                                Odd
# 662                           Night                               Even
# 884                           Night                               Even
# 422                           Night                                Odd
# ...                             ...                                ...
# 983                           Night                               Even
# 420                           Night                                Odd
# 1028                        Morning                               Even
# 150                           Night                               Even
# 29                            Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 151                  No                          Summer
# 19                   No                          Summer
# 662                 Yes                          Summer
# 884                  No                          Summer
# 422                  No                          Winter
# ...                 ...                             ...
# 983                 Yes                          Summer
# 420                  No                          Summer
# 1028                 No                          Summer
# 150                 Yes                          Summer
# 29                   No                          Summer
#
#      Are you a business major?  ...  \
# 151                         No  ...
# 19                         Yes  ...
# 662                         No  ...
# 884                        Yes  ...
# 422                         No  ...
# ...                        ...  ...
# 983                         No  ...
# 420                        Yes  ...
# 1028                        No  ...
# 150                         No  ...
# 29                         Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 151                                             Germany
# 19                                                Italy
# 662                                                  UK
# 884                                     United Kingdom
# 422                                               China
# ...                                                 ...
# 983                                           Singapore
# 420                                             England
# 1028                                        new zealand
# 150                                             Germany
# 29                                                Japan
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 151                          Blue   Hanging out with friends and family
# 19                           Blue                               Golfing
# 662                           Red                              Laughing
# 884                           Red              spend time with friends
# 422                         White                       Play video game
# ...                           ...                                   ...
# 983                   Light green                    Going to the beach
# 420                          blue                          with friends
# 1028                         pink                               reading
# 150                          Blue                          with friends
# 29                         Purple                                 Sleep
#
#      What genre of music do you like the most?  \
# 151                                        Pop
# 19                                     Country
# 662                                       Rock
# 884                                        pop
# 422                                  pop music
# ...                                        ...
# 983                                        Rap
# 420                                       folk
# 1028                                       rap
# 150                                    Hip Hop
# 29                                        Kpop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 151                                              Monkey
# 19                                                 Lion
# 662                                             giraffe
# 884                                            dolphin
# 422                                               tiger
# ...                                                 ...
# 983                                              Wombat
# 420                                                 cat
# 1028                                             monkey
# 150                                                 Dog
# 29                                                  Cat
#
#      What do you think is the hardest major at UIUC?  \
# 151                             Computer Engineering
# 19                                  Computer Science
# 662                                               CS
# 884                             chemical engineering
# 422                                              ECE
# ...                                              ...
# 983                                               CS
# 420                                      engineering
# 1028                            computer engineering
# 150                                      Engineering
# 29                                       Engineering
#
#      Who is your favorite music artist?  \
# 151                             Anirudh
# 19                           Zach Bryan
# 662                         The Beatles
# 884                       Lana Del Rey
# 422                           Seventeen
# ...                                 ...
# 983                          Kali Uchis
# 420                               lorde
# 1028                         the weeknd
# 150                          Kanye West
# 29                              Enhypen
#
#      What's your favorite social media app?  \
# 151                               Instagram
# 19                                 Snapchat
# 662                                  Reddit
# 884                                  tiktok
# 422                                  Wechat
# ...                                     ...
# 983                               Instagram
# 420                               instagram
# 1028                               snapchat
# 150                                snapchat
# 29                                   TikTok
#
#      What is your favorite game to play (either video game or IRL)?  \
# 151                                              Soccer
# 19                                    Pickup Basketball
# 662                                               Chess
# 884                                              tennis
# 422                                          video game
# ...                                                 ...
# 983                                            Fortnite
# 420                                              hayday
# 1028                                      hide and seek
# 150                                   Settlers of Catan
# 29                                     Dress To Impress
#
#      Where is your dream vacation spot?
# 151                                Bali
# 19                                 Rome
# 662                             Iceland
# 884                              Italy
# 422                               China
# ...                                 ...
# 983                               Japan
# 420                               Japan
# 1028                             brazil
# 150                              Europe
# 29                          Switzerland
#
# [535 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#              Name          Lab When flipping a coin, heads or tails?  \
# 0     Prof. Karle     AL1, AL2                                 Heads
# 1      Prof. Wade     AL1, AL2                                 Tails
# 2        Angelina          Y13                                 Tails
# 3        TA Tyler          Y07                                 Tails
# 5            Gage          Y10                                 Heads
# ...           ...          ...                                   ...
# 1047         Sana          Y04                                 Heads
# 1051     Preetesh          Y16                                 Heads
# 1052      CA Soph  Y05 Y07 Y14                                 Heads
# 1059      CA Lara     Y19, Y20                                 Tails
# 1068        Bowen          Y25                                 Heads
#
#      Is this your first year at UIUC?  \
# 0                      Not First Year
# 1                      Not First Year
# 2                  First Year at UIUC
# 3                      Not First Year
# 5                  First Year at UIUC
# ...                               ...
# 1047                   Not First Year
# 1051               First Year at UIUC
# 1052                   Not First Year
# 1059                   Not First Year
# 1068               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 0                                             Chocolate
# 1                                               Vanilla
# 2                                               Vanilla
# 3                                             Chocolate
# 5                                               Vanilla
# ...                                                 ...
# 1047                                            Vanilla
# 1051                                            Vanilla
# 1052                                          Chocolate
# 1059                                          Chocolate
# 1068                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 0                             Night                               Even
# 1                             Night                                Odd
# 2                           Morning                               Even
# 3                             Night                               Even
# 5                             Night                               Even
# ...                             ...                                ...
# 1047                          Night                                Odd
# 1051                        Morning                                Odd
# 1052                          Night                               Even
# 1059                          Night                               Even
# 1068                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 0                    No                          Summer
# 1                   Yes                          Winter
# 2                   Yes                          Summer
# 3                    No                          Winter
# 5                   Yes                          Winter
# ...                 ...                             ...
# 1047                Yes                          Summer
# 1051                 No                          Summer
# 1052                Yes                          Winter
# 1059                 No                          Summer
# 1068                 No                          Summer
#
#      Are you a business major?  ...  \
# 0                           No  ...
# 1                           No  ...
# 2                           No  ...
# 3                           No  ...
# 5                           No  ...
# ...                        ...  ...
# 1047                        No  ...
# 1051                        No  ...
# 1052                        No  ...
# 1059                        No  ...
# 1068                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 0                                          The Maldives
# 1                                                Sweden
# 2                                            Hong Kong
# 3                                                Canada
# 5                                               Canada
# ...                                                 ...
# 1047                                              Dubai
# 1051                                              Japan
# 1052                                            Finland
# 1059                                             Canada
# 1068                                              China
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 0                            pink                         water skiing!
# 1                          Purple                           Programming
# 2                            Pink                        Watching shows
# 3                          Orange                              Terraria
# 5                           Green                   Fishing or Hunting
# ...                           ...                                   ...
# 1047                        White                       With my friends
# 1051                          Red                               Workout
# 1052                          Red                          With friends
# 1059                        beige                               reading
# 1068                       Purple                                 Films
#
#      What genre of music do you like the most?  \
# 0                                          pop
# 1                                          Pop
# 2                                          r&b
# 3                                     Pop rock
# 5                                 Grunge Rock
# ...                                        ...
# 1047                                       Rap
# 1051                                       Pop
# 1052                                     Indie
# 1059                                Riot grrrl
# 1068                                      Rocj
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 0                                                 sloth
# 1                                                   Fox
# 2                                                 Tiger
# 3                                                   Bee
# 5                                                 Bear
# ...                                                 ...
# 1047                                             Monkey
# 1051                                                Cat
# 1052                                              Shark
# 1059                                        sea anemone
# 1068                                              Puppy
#
#      What do you think is the hardest major at UIUC?  \
# 0                                   Computer Science
# 1                                   Computer Science
# 2                             Aerospace engineering
# 3                               Chemical Engineering
# 5                                              Math
# ...                                              ...
# 1047                          Mechanical Engineering
# 1051                                              CS
# 1052                             Bioengineering + CS
# 1059                                         Physics
# 1068                                     Engineering
#
#      Who is your favorite music artist?  \
# 0                          Taylor Swift
# 1                          Taylor Swift
# 2                         Ashley Alisha
# 3                            Billy Joel
# 5                            Jim Croce
# ...                                 ...
# 1047                          21 Savage
# 1051                      Billie Ellish
# 1052                                BTS
# 1059                            Slant 6
# 1068                         Kanye West
#
#      What's your favorite social media app?  \
# 0                                 Instagram
# 1                                   YouTube
# 2                                     Insta
# 3                                    Reddit
# 5                                    Tiktok
# ...                                     ...
# 1047                                Tik Tok
# 1051                              Instagram
# 1052                                 TikTok
# 1059                                 Reddit
# 1068                                    ins
#
#      What is your favorite game to play (either video game or IRL)?  \
# 0                                            volleyball
# 1                                              Factorio
# 2                                                   NaN
# 3                                              Terraria
# 5                                           Titanfall 2
# ...                                                 ...
# 1047                                        Ice Skating
# 1051                                         Volleyball
# 1052                                          Minecraft
# 1059                                           Oxenfree
# 1068                                     Stardew Valley
#
#      Where is your dream vacation spot?
# 0                          The Maldives
# 1                                Acadia
# 2                       Southern France
# 3                          My apartment
# 5                 Denali National Park
# ...                                 ...
# 1047                      Bali or Egypt
# 1051                              Italy
# 1052                            Croatia
# 1059                              Japan
# 1068                              Tokyo
#
# [263 rows x 150 columns]

# %% [markdown]
# **Q4: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# After randomly selecting the treatment group from the original df, we did not remove those in the treatment group from the original df. Then, when we randomly selected the control group, we selected from the original df, which still had people who had been selected for the treatment group. So there is overlap between the groups.

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[ ~df.index.isin(treatment.index) ]
control
# Out:
#            Name       Lab When flipping a coin, heads or tails?  \
# 4        Sneha        Y17                                 Tails
# 7         Jaden       Y34                                 Heads
# 8          Eman       Y11                                 Heads
# 9        Amanda       Y23                                 Heads
# 10    Stephanie       Y36                                 Heads
# ...         ...       ...                                   ...
# 1064     Wesley       Y02                                 Tails
# 1065   Man Geun       Y04                                 Heads
# 1066   CA Elise  Y11, Y33                                 Heads
# 1067    Chinmay       Y11                                 Heads
# 1069   kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 4                  First Year at UIUC
# 7                  First Year at UIUC
# 8                  First Year at UIUC
# 9                  First Year at UIUC
# 10                 First Year at UIUC
# ...                               ...
# 1064                   Not First Year
# 1065                   Not First Year
# 1066                   Not First Year
# 1067               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 4                                               Vanilla
# 7                                             Chocolate
# 8                                             Chocolate
# 9                                               Vanilla
# 10                                            Chocolate
# ...                                                 ...
# 1064                                            Vanilla
# 1065                                            Vanilla
# 1066                                            Vanilla
# 1067                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 4                             Night                               Even
# 7                           Morning                               Even
# 8                           Morning                               Even
# 9                             Night                               Even
# 10                            Night                               Even
# ...                             ...                                ...
# 1064                          Night                               Even
# 1065                          Night                               Even
# 1066                          Night                               Even
# 1067                          Night                               Even
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 4                    No                          Summer
# 7                    No                          Summer
# 8                    No                          Summer
# 9                   Yes                          Summer
# 10                   No                          Summer
# ...                 ...                             ...
# 1064                 No                          Summer
# 1065                 No                          Winter
# 1066                Yes                          Summer
# 1067                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 4                          Yes  ...
# 7                           No  ...
# 8                           No  ...
# 9                          Yes  ...
# 10                          No  ...
# ...                        ...  ...
# 1064                        No  ...
# 1065                        No  ...
# 1066                        No  ...
# 1067                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 4                                                Canada
# 7                                                 japan
# 8                                                   UAE
# 9                                                   NaN
# 10                                                Japan
# ...                                                 ...
# 1064                                              japan
# 1065                                              Korea
# 1066                                            England
# 1067                                              India
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 4                           Green                 Reading or crocheting
# 7                            blue                     talk with friends
# 8                             Red                Hang out with friends
# 9                           Green                     Watching TV shows
# 10                           pink              hanging out with friends
# ...                           ...                                   ...
# 1064                         blue                                 sleep
# 1065                         Blue                           Playstation
# 1066                         Pink                          With friends
# 1067                         Blue                                 Music
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 4                                     Pop Rock
# 7                                          pop
# 8                                          R&B
# 9                                          Pop
# 10                                         r&b
# ...                                        ...
# 1064                                       pop
# 1065                                       Pop
# 1066                                 Indie pop
# 1067                                       Rap
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 4                                               Penguin
# 7                                                   dog
# 8                                               Unicorn
# 9                                               Dolphin
# 10                                                  cat
# ...                                                 ...
# 1064                                         dog/ camel
# 1065                                                Dog
# 1066                                               Wolf
# 1067                                                Dog
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 4                                   Computer Science
# 7                                                 CS
# 8                                            Physics
# 9                                        Engineering
# 10                                  Computer Science
# ...                                              ...
# 1064                                         english
# 1065                                              CS
# 1066                                            Eecs
# 1067                                Computer Science
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 4                       Imagine Dragons
# 7                                 keshi
# 8                                   SZA
# 9                                   NaN
# 10                                  SZA
# ...                                 ...
# 1064                         juice wrld
# 1065                                 IU
# 1066                       Taylor swift
# 1067                       Travis Scott
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 4                                 Instagram
# 7                                    wechat
# 8                                 Instagram
# 9                                 Instagram
# 10                                   tiktok
# ...                                     ...
# 1064                                youtube
# 1065                              Instagram
# 1066                              Pinterest
# 1067                              Instagram
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 4                                            Beat Saber
# 7                                                   LOL
# 8                                                  Sims
# 9                                                   NaN
# 10                                          crossy road
# ...                                                 ...
# 1064                                        brawl stars
# 1065                                              NBA2k
# 1066                                           Pinochle
# 1067                                             Tennis
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 4                                 Italy
# 7                                 china
# 8                               Greece
# 9                                 Italy
# 10                                Japan
# ...                                 ...
# 1064                              japan
# 1065                             Cancun
# 1066                              Kenya
# 1067                             Monaco
# 1069                            iceland
#
# [535 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you?
# - If you did not fill out the "Hello Survey", then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead  *(those are the names we used in the `Name` column).*

# %%
# Use this cell to find yourself in either `treatment` or `control` groups. 
# ...feel free to add extra "Code" cells here if needed.


# Note to grader: I wanted to be anonymous on the survey, so I went under the name "Sarah". 
# The music genre identifies me most, along with country I would like to live in since most people I know don't have this combo

dfme = df[(df.Name == "Sarah") & (df["Besides the US, what country would you like to live in?"] == "Canada") & (df["What genre of music do you like the most?"] == "Bollywood")]
dfme
# control.index.isin( dfme["What genre of music do you like the most?"] == "Bollywood")
treatment.index.isin( dfme["What genre of music do you like the most?"] == "Bollywood")
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False])

# %% [markdown]
# ## Analysis: Finding Yourself!
#
# **Q5: Which group where you in -- treatment or control?**

# %% [markdown]
# I am in the treatment group, since the results have only one "True" value in the array, while there are 0 "True" values in the control group.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking refers to creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac=0.5)
df1_treatment
# Out:
#           Name       Lab When flipping a coin, heads or tails?  \
# 1035     Janna       Y08                                 Heads
# 617    Lillian       Y11                                 Heads
# 524   Manushri       Y18                                 Heads
# 12      Amanda       Y30                                 Heads
# 1059   CA Lara  Y19, Y20                                 Tails
# ...        ...       ...                                   ...
# 309      Sarah       Y19                                 Heads
# 66       Ruien       Y09                                 Heads
# 637       Koey       Y17                                 Heads
# 504     Xingyi       Y25                                 Heads
# 811    Shannon       Y31                                 Heads
#
#      Is this your first year at UIUC?  \
# 1035                   Not First Year
# 617                First Year at UIUC
# 524                First Year at UIUC
# 12                     Not First Year
# 1059                   Not First Year
# ...                               ...
# 309                First Year at UIUC
# 66                 First Year at UIUC
# 637                First Year at UIUC
# 504                    Not First Year
# 811                First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1035                                            Vanilla
# 617                                           Chocolate
# 524                                             Vanilla
# 12                                              Vanilla
# 1059                                          Chocolate
# ...                                                 ...
# 309                                             Vanilla
# 66                                            Chocolate
# 637                                             Vanilla
# 504                                           Chocolate
# 811                                             Vanilla
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1035                        Morning                               Even
# 617                           Night                                Odd
# 524                           Night                                Odd
# 12                            Night                               Even
# 1059                          Night                               Even
# ...                             ...                                ...
# 309                           Night                               Even
# 66                            Night                               Even
# 637                           Night                               Even
# 504                           Night                               Even
# 811                           Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1035                Yes                          Summer
# 617                  No                          Winter
# 524                  No                          Summer
# 12                  Yes                          Summer
# 1059                 No                          Summer
# ...                 ...                             ...
# 309                  No                          Winter
# 66                   No                          Winter
# 637                 Yes                          Summer
# 504                 Yes                          Summer
# 811                  No                          Summer
#
#      Are you a business major?  ...  \
# 1035                        No  ...
# 617                         No  ...
# 524                         No  ...
# 12                          No  ...
# 1059                        No  ...
# ...                        ...  ...
# 309                        Yes  ...
# 66                          No  ...
# 637                         No  ...
# 504                         No  ...
# 811                         No  ...
#
#      Besides the US, what country would you like to live in?  \
# 1035                                            Germany
# 617                                              Taiwan
# 524                                          Singapore
# 12                                                Italy
# 1059                                             Canada
# ...                                                 ...
# 309                                             England
# 66                                                China
# 637                                               Japan
# 504                                               Italy
# 811                                         Switzerland
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 1035                        Green                                  Yoga
# 617                         black                          watch animes
# 524                          blue                       watch tv shows
# 12                         Purple                              Sleeping
# 1059                        beige                               reading
# ...                           ...                                   ...
# 309                        yellow                               netflix
# 66                  Light yellow.                          Watch videos
# 637                         Green                           Read novels
# 504                          blue                                 sleep
# 811                        Purple                       Going for a run
#
#      What genre of music do you like the most?  \
# 1035                                       EDM
# 617                                        pop
# 524                                        pop
# 12                                 Alternative
# 1059                                Riot grrrl
# ...                                        ...
# 309                                        rap
# 66                                 Pure music.
# 637                                        pop
# 504                                        pop
# 811                                    Country
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1035                                          House Cat
# 617                                           dachshund
# 524                                            dolphin
# 12                                                Bunny
# 1059                                        sea anemone
# ...                                                 ...
# 309                                            elephant
# 66                                                 Cat.
# 637                                                 Cat
# 504                                                cats
# 811                                              Gopher
#
#      What do you think is the hardest major at UIUC?  \
# 1035                                              CS
# 617                             chemical engineering
# 524                             computer engineering
# 12                              Computer Engineering
# 1059                                         Physics
# ...                                              ...
# 309                                 Computer Science
# 66                                      Mathematics.
# 637                                               CS
# 504                                               cs
# 811                           Electrical Engineering
#
#      Who is your favorite music artist?  \
# 1035                               Rezz
# 617                                 bts
# 524                        the weekend
# 12                               Hozier
# 1059                            Slant 6
# ...                                 ...
# 309                               drake
# 66                            HOYO-MIX.
# 637                       Yuuri (j-pop)
# 504                              Taylor
# 811                              Hozier
#
#      What's your favorite social media app?  \
# 1035                                   VSCO
# 617                               instagram
# 524                               instagram
# 12                                  Twitter
# 1059                                 Reddit
# ...                                     ...
# 309                               instagram
# 66                                  Wechat.
# 637                                 YouTube
# 504                             xiaohongshu
# 811                                Snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1035                            Ghosts in the graveyard
# 617                                   exploding kittens
# 524                                                 uno
# 12                                       Stardew Valley
# 1059                                           Oxenfree
# ...                                                 ...
# 309                                              spoons
# 66                                          Identity V.
# 637                                      Colorful Stage
# 504                                             majiang
# 811                                          Poptropica
#
#                  Where is your dream vacation spot?
# 1035                                        Croatia
# 617                                           kyoto
# 524                                           paris
# 12                                           Japan
# 1059                                          Japan
# ...                                             ...
# 309                                         bahamas
# 66    A hotel room near the beach with AC and wifi.
# 637                               Anywhere in Japan
# 504                                      California
# 811                                         Iceland
#
# [231 rows x 150 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control = df1[ ~df1.index.isin(df1_treatment.index) ]
df1_control

# control = df[ ~df.index.isin(treatment.index) ]
# control
# Out:
#           Name       Lab When flipping a coin, heads or tails?  \
# 2     Angelina       Y13                                 Tails
# 4       Sneha        Y17                                 Tails
# 8         Eman       Y11                                 Heads
# 13    Kristina       Y33                                 Tails
# 16     Aaliyay       Y30                                 Heads
# ...        ...       ...                                   ...
# 1032      Jiya       Y07                                 Tails
# 1040   Anushri       Y22                                 Heads
# 1048    Molina       Y09                                 Heads
# 1054  CA Maddy       Y36                                 Heads
# 1056  TA Deeya  Y19, Y29                                 Tails
#
#      Is this your first year at UIUC?  \
# 2                  First Year at UIUC
# 4                  First Year at UIUC
# 8                  First Year at UIUC
# 13                     Not First Year
# 16                 First Year at UIUC
# ...                               ...
# 1032               First Year at UIUC
# 1040               First Year at UIUC
# 1048               First Year at UIUC
# 1054                   Not First Year
# 1056                   Not First Year
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 2                                               Vanilla
# 4                                               Vanilla
# 8                                             Chocolate
# 13                                              Vanilla
# 16                                              Vanilla
# ...                                                 ...
# 1032                                          Chocolate
# 1040                                          Chocolate
# 1048                                          Chocolate
# 1054                                            Vanilla
# 1056                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 2                           Morning                               Even
# 4                             Night                               Even
# 8                           Morning                               Even
# 13                            Night                               Even
# 16                            Night                               Even
# ...                             ...                                ...
# 1032                          Night                               Even
# 1040                          Night                               Even
# 1048                          Night                               Even
# 1054                        Morning                               Even
# 1056                          Night                               Even
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 2                   Yes                          Summer
# 4                    No                          Summer
# 8                    No                          Summer
# 13                   No                          Winter
# 16                  Yes                          Summer
# ...                 ...                             ...
# 1032                 No                          Summer
# 1040                Yes                          Summer
# 1048                 No                          Summer
# 1054                 No                          Summer
# 1056                Yes                          Winter
#
#      Are you a business major?  ...  \
# 2                           No  ...
# 4                          Yes  ...
# 8                           No  ...
# 13                          No  ...
# 16                          No  ...
# ...                        ...  ...
# 1032                       Yes  ...
# 1040                        No  ...
# 1048                        No  ...
# 1054                        No  ...
# 1056                        No  ...
#
#      Besides the US, what country would you like to live in?  \
# 2                                            Hong Kong
# 4                                                Canada
# 8                                                   UAE
# 13                                             Ireland
# 16                                              Canada
# ...                                                 ...
# 1032                                                UAE
# 1040                                             France
# 1048                                        Switzerland
# 1054                                             greece
# 1056                                        New Zealand
#
#      What is your favorite color?       Favorite way to spend your free time?  \
# 2                            Pink                              Watching shows
# 4                           Green                       Reading or crocheting
# 8                             Red                      Hang out with friends
# 13                     sage green                     Hanging with my friends
# 16                           blue                                    on phone
# ...                           ...                                         ...
# 1032                        green                                with friends
# 1040                       purple                              Playing tennis
# 1048                       Purple                                     Singing
# 1054                         pink                                 working out
# 1056                          Red  Spending time with my friends doing crafts
#
#      What genre of music do you like the most?  \
# 2                                          r&b
# 4                                     Pop Rock
# 8                                          R&B
# 13                  alternative and indie folk
# 16                                         rnb
# ...                                        ...
# 1032                                       R&B
# 1040                                       Pop
# 1048                                       Pop
# 1054                                       pop
# 1056                                      Kpop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 2                                                 Tiger
# 4                                               Penguin
# 8                                               Unicorn
# 13                                               kitten
# 16                                                 bird
# ...                                                 ...
# 1032                                           squirrel
# 1040                                                Fox
# 1048                                                Cat
# 1054                                                cat
# 1056                                   I would be a cat
#
#      What do you think is the hardest major at UIUC?  \
# 2                             Aerospace engineering
# 4                                   Computer Science
# 8                                            Physics
# 13                                           pre-med
# 16                             aerospace engineering
# ...                                              ...
# 1032                                              cs
# 1040                                              CS
# 1048                                              CS
# 1054                                        comp sci
# 1056                                             ECE
#
#      Who is your favorite music artist?  \
# 2                         Ashley Alisha
# 4                       Imagine Dragons
# 8                                   SZA
# 13                        Joni Mitchell
# 16                          Frank Ocean
# ...                                 ...
# 1032                        frank ocean
# 1040                  Sabrina Carpenter
# 1048                           Jay Chou
# 1054                       taylor swift
# 1056                                SZA
#
#      What's your favorite social media app?  \
# 2                                     Insta
# 4                                 Instagram
# 8                                 Instagram
# 13                                instagram
# 16                                   tiktok
# ...                                     ...
# 1032                              instagram
# 1040                              Instagram
# 1048                                    Ins
# 1054                                 tiktok
# 1056                              Instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 2                                                   NaN
# 4                                            Beat Saber
# 8                                                  Sims
# 13                                     Dress to Impress
# 16                                               sims 4
# ...                                                 ...
# 1032                                                tag
# 1040                                Rock Paper Scissors
# 1048                                         Video game
# 1054                                        super mario
# 1056                                        Royal Match
#
#      Where is your dream vacation spot?
# 2                       Southern France
# 4                                 Italy
# 8                               Greece
# 13                      South of France
# 16                               eurpoe
# ...                                 ...
# 1032                              italy
# 1040                             Mexico
# 1048                        Switzerland
# 1054                             greece
# 1056                           Thailand
#
# [231 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac = 0.5)
df2_treatment
# Out:
#         Name  Lab When flipping a coin, heads or tails?  \
# 416     Kush  Y15                                 Heads
# 219  Praveen  Y32                                 Heads
# 314   Keegan  Y21                                 Tails
# 918   Zhirui  Y35                                 Heads
# 102     Matt  Y16                                 Heads
# ..       ...  ...                                   ...
# 248   Jayden  Y34                                 Tails
# 767  yuefeng  Y16                                 Heads
# 891   Samuel  Y35                                 Heads
# 93     Lukas  Y36                                 Heads
# 796    Grant  Y24                                 Heads
#
#     Is this your first year at UIUC?  \
# 416               First Year at UIUC
# 219                   Not First Year
# 314               First Year at UIUC
# 918               First Year at UIUC
# 102               First Year at UIUC
# ..                               ...
# 248               First Year at UIUC
# 767                   Not First Year
# 891                   Not First Year
# 93                First Year at UIUC
# 796               First Year at UIUC
#
#     Is your favorite ice cream flavor chocolate or vanilla?  \
# 416                                          Chocolate
# 219                                            Vanilla
# 314                                          Chocolate
# 918                                          Chocolate
# 102                                          Chocolate
# ..                                                 ...
# 248                                            Vanilla
# 767                                          Chocolate
# 891                                            Vanilla
# 93                                           Chocolate
# 796                                          Chocolate
#
#     Do you like morning or night?  Do you prefer even or odd numbers?  \
# 416                        Morning                               Even
# 219                          Night                               Even
# 314                          Night                               Even
# 918                          Night                                Odd
# 102                          Night                               Even
# ..                             ...                                ...
# 248                          Night                               Even
# 767                          Night                               Even
# 891                        Morning                               Even
# 93                           Night                               Even
# 796                          Night                                Odd
#
#     Do you have a pet? Do you prefer summer or winter?  \
# 416                 No                          Winter
# 219                 No                          Summer
# 314                Yes                          Summer
# 918                 No                          Winter
# 102                Yes                          Summer
# ..                 ...                             ...
# 248                Yes                          Summer
# 767                 No                          Winter
# 891                 No                          Summer
# 93                 Yes                          Summer
# 796                Yes                          Winter
#
#     Are you a business major?  ...  \
# 416                       Yes  ...
# 219                        No  ...
# 314                        No  ...
# 918                        No  ...
# 102                       Yes  ...
# ..                        ...  ...
# 248                       Yes  ...
# 767                        No  ...
# 891                        No  ...
# 93                        Yes  ...
# 796                       Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 416                                              India
# 219                                              India
# 314                                            Finland
# 918                                        Switzerland
# 102                                            England
# ..                                                 ...
# 248                                            Iceland
# 767                                              China
# 891                                                 UK
# 93                                               Japan
# 796                                              italy
#
#     What is your favorite color? Favorite way to spend your free time?  \
# 416                         Blue                          Lift weights
# 219                        Green                          With friends
# 314                       Orange                            Pickleball
# 918                         blue              hang out with my friends
# 102                         Blue    playing golf or cards with friends
# ..                           ...                                   ...
# 248                       Yellow                       play basketball
# 767                         Blue                                  Game
# 891                         Blue                    Reading and gaming
# 93                          blue                         playing games
# 796                   aquamarine                  hangout with friends
#
#     What genre of music do you like the most?  \
# 416                                       EDM
# 219                                       Rap
# 314                                      Folk
# 918                                       pop
# 102                                       Rap
# ..                                        ...
# 248                                       r&b
# 767                                   Country
# 891                                       Pop
# 93                                      indie
# 796                                       pop
#
#     If you were an animal, which would you be? / What is your spirit animal?  \
# 416                                               Bear
# 219                                              Eagle
# 314                                                Dog
# 918                                                dog
# 102                                             Donkey
# ..                                                 ...
# 248                                             Jaguar
# 767                                               Cats
# 891                                             Falcon
# 93                                                 cat
# 796                                         koala bear
#
#     What do you think is the hardest major at UIUC?  \
# 416                                              CS
# 219                                             ECE
# 314                             Nuclear Engineering
# 918                                              CS
# 102                                        Business
# ..                                              ...
# 248                                 Bio-engineering
# 767                                      Psychology
# 891                                Computer Science
# 93                               Law and philosophy
# 796                            computer engineering
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 416                              Kanii                                  Insta
# 219                         Tory Lanez                                Youtube
# 314                         Mac Miller                              Instagram
# 918                    Michael Jackson                                 WeChat
# 102                           Coldplay                              Instagram
# ..                                 ...                                    ...
# 248                           Rod Wave                                 Tiktok
# 767                                Ed                                  Tiktok
# 891                        The Weekend                              Instagram
# 93                                 NaN                                  insta
# 796                            enhypen                              instagram
#
#     What is your favorite game to play (either video game or IRL)?  \
# 416                                             Roblox
# 219                                              Catch
# 314                                           Valorant
# 918                                    Heart of Iron 4
# 102                                             Euchre
# ..                                                 ...
# 248                                                 2k
# 767                                               Csgo
# 891                                       Ready or Not
# 93                                                 LOL
# 796                                          minecraft
#
#     Where is your dream vacation spot?
# 416                             Mexico
# 219                             Hawaii
# 314                              Spain
# 918                              japan
# 102                    Turks and Cacos
# ..                                 ...
# 248                             Sweden
# 767                            Nothing
# 891                              Beach
# 93                               Balli
# 796                              japan
#
# [302 rows x 150 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control = df2[ ~df2.index.isin(df2_treatment.index) ]
df2_control

# control = df[ ~df.index.isin(treatment.index) ]
# control
# Out:
#             Name       Lab When flipping a coin, heads or tails?  \
# 1     Prof. Wade  AL1, AL2                                 Tails
# 5           Gage       Y10                                 Heads
# 7          Jaden       Y34                                 Heads
# 17        Albert       Y10                                 Heads
# 19         Brady       Y16                                 Heads
# ...          ...       ...                                   ...
# 1060    TA Jimmy       Y21                                 Tails
# 1061   TA Kunlun  Y12, Y25                                 Heads
# 1064      Wesley       Y02                                 Tails
# 1068       Bowen       Y25                                 Heads
# 1069    kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 1                      Not First Year
# 5                  First Year at UIUC
# 7                  First Year at UIUC
# 17                 First Year at UIUC
# 19                 First Year at UIUC
# ...                               ...
# 1060               First Year at UIUC
# 1061               First Year at UIUC
# 1064                   Not First Year
# 1068               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1                                               Vanilla
# 5                                               Vanilla
# 7                                             Chocolate
# 17                                              Vanilla
# 19                                              Vanilla
# ...                                                 ...
# 1060                                          Chocolate
# 1061                                          Chocolate
# 1064                                            Vanilla
# 1068                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1                             Night                                Odd
# 5                             Night                               Even
# 7                           Morning                               Even
# 17                            Night                                Odd
# 19                          Morning                                Odd
# ...                             ...                                ...
# 1060                          Night                               Even
# 1061                        Morning                               Even
# 1064                          Night                               Even
# 1068                          Night                                Odd
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1                   Yes                          Winter
# 5                   Yes                          Winter
# 7                    No                          Summer
# 17                   No                          Summer
# 19                   No                          Summer
# ...                 ...                             ...
# 1060                 No                          Summer
# 1061                Yes                          Summer
# 1064                 No                          Summer
# 1068                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 1                           No  ...
# 5                           No  ...
# 7                           No  ...
# 17                          No  ...
# 19                         Yes  ...
# ...                        ...  ...
# 1060                        No  ...
# 1061                        No  ...
# 1064                        No  ...
# 1068                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 1                                                Sweden
# 5                                               Canada
# 7                                                 japan
# 17                                               Poland
# 19                                                Italy
# ...                                                 ...
# 1060                                                 UK
# 1061                                              China
# 1064                                              japan
# 1068                                              China
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 1                          Purple                           Programming
# 5                           Green                   Fishing or Hunting
# 7                            blue                     talk with friends
# 17                            Red                                Soccer
# 19                           Blue                               Golfing
# ...                           ...                                   ...
# 1060                        Black                        Watching shows
# 1061                         blue                                  game
# 1064                         blue                                 sleep
# 1068                       Purple                                 Films
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 1                                          Pop
# 5                                 Grunge Rock
# 7                                          pop
# 17                                         Rap
# 19                                     Country
# ...                                        ...
# 1060                                       Pop
# 1061                                      jazz
# 1064                                       pop
# 1068                                      Rocj
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1                                                   Fox
# 5                                                 Bear
# 7                                                   dog
# 17                                                Tiger
# 19                                                 Lion
# ...                                                 ...
# 1060                                              Panda
# 1061                                               egal
# 1064                                         dog/ camel
# 1068                                              Puppy
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 1                                   Computer Science
# 5                                              Math
# 7                                                 CS
# 17                              Chemical Engineering
# 19                                  Computer Science
# ...                                              ...
# 1060                                         Physics
# 1061                                              cs
# 1064                                         english
# 1068                                     Engineering
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 1                          Taylor Swift
# 5                            Jim Croce
# 7                                 keshi
# 17                         Travis Scott
# 19                           Zach Bryan
# ...                                 ...
# 1060                         Kanye West
# 1061                           Coldplay
# 1064                         juice wrld
# 1068                         Kanye West
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 1                                   YouTube
# 5                                    Tiktok
# 7                                    wechat
# 17                                Instagram
# 19                                 Snapchat
# ...                                     ...
# 1060                                Discord
# 1061                                 Wechat
# 1064                                youtube
# 1068                                    ins
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1                                              Factorio
# 5                                           Titanfall 2
# 7                                                   LOL
# 17                                               Soccer
# 19                                    Pickup Basketball
# ...                                                 ...
# 1060                                              Poker
# 1061                                          overwatch
# 1064                                        brawl stars
# 1068                                     Stardew Valley
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 1                                Acadia
# 5                 Denali National Park
# 7                                 china
# 17                              Croatia
# 19                                 Rome
# ...                                 ...
# 1060                              Japan
# 1061                                 CA
# 1064                              japan
# 1068                              Tokyo
# 1069                            iceland
#
# [303 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`.
#
#
#
# FYI, you will not need to reset the index here!

# %%
treatment = pd.concat([df1_treatment, df2_treatment])
treatment
# Out:
#           Name       Lab When flipping a coin, heads or tails?  \
# 1035     Janna       Y08                                 Heads
# 617    Lillian       Y11                                 Heads
# 524   Manushri       Y18                                 Heads
# 12      Amanda       Y30                                 Heads
# 1059   CA Lara  Y19, Y20                                 Tails
# ...        ...       ...                                   ...
# 248     Jayden       Y34                                 Tails
# 767    yuefeng       Y16                                 Heads
# 891     Samuel       Y35                                 Heads
# 93       Lukas       Y36                                 Heads
# 796      Grant       Y24                                 Heads
#
#      Is this your first year at UIUC?  \
# 1035                   Not First Year
# 617                First Year at UIUC
# 524                First Year at UIUC
# 12                     Not First Year
# 1059                   Not First Year
# ...                               ...
# 248                First Year at UIUC
# 767                    Not First Year
# 891                    Not First Year
# 93                 First Year at UIUC
# 796                First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 1035                                            Vanilla
# 617                                           Chocolate
# 524                                             Vanilla
# 12                                              Vanilla
# 1059                                          Chocolate
# ...                                                 ...
# 248                                             Vanilla
# 767                                           Chocolate
# 891                                             Vanilla
# 93                                            Chocolate
# 796                                           Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 1035                        Morning                               Even
# 617                           Night                                Odd
# 524                           Night                                Odd
# 12                            Night                               Even
# 1059                          Night                               Even
# ...                             ...                                ...
# 248                           Night                               Even
# 767                           Night                               Even
# 891                         Morning                               Even
# 93                            Night                               Even
# 796                           Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 1035                Yes                          Summer
# 617                  No                          Winter
# 524                  No                          Summer
# 12                  Yes                          Summer
# 1059                 No                          Summer
# ...                 ...                             ...
# 248                 Yes                          Summer
# 767                  No                          Winter
# 891                  No                          Summer
# 93                  Yes                          Summer
# 796                 Yes                          Winter
#
#      Are you a business major?  ...  \
# 1035                        No  ...
# 617                         No  ...
# 524                         No  ...
# 12                          No  ...
# 1059                        No  ...
# ...                        ...  ...
# 248                        Yes  ...
# 767                         No  ...
# 891                         No  ...
# 93                         Yes  ...
# 796                        Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 1035                                            Germany
# 617                                              Taiwan
# 524                                          Singapore
# 12                                                Italy
# 1059                                             Canada
# ...                                                 ...
# 248                                             Iceland
# 767                                               China
# 891                                                  UK
# 93                                                Japan
# 796                                               italy
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 1035                        Green                                  Yoga
# 617                         black                          watch animes
# 524                          blue                       watch tv shows
# 12                         Purple                              Sleeping
# 1059                        beige                               reading
# ...                           ...                                   ...
# 248                        Yellow                       play basketball
# 767                          Blue                                  Game
# 891                          Blue                    Reading and gaming
# 93                           blue                         playing games
# 796                    aquamarine                  hangout with friends
#
#      What genre of music do you like the most?  \
# 1035                                       EDM
# 617                                        pop
# 524                                        pop
# 12                                 Alternative
# 1059                                Riot grrrl
# ...                                        ...
# 248                                        r&b
# 767                                    Country
# 891                                        Pop
# 93                                       indie
# 796                                        pop
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 1035                                          House Cat
# 617                                           dachshund
# 524                                            dolphin
# 12                                                Bunny
# 1059                                        sea anemone
# ...                                                 ...
# 248                                              Jaguar
# 767                                                Cats
# 891                                              Falcon
# 93                                                  cat
# 796                                          koala bear
#
#      What do you think is the hardest major at UIUC?  \
# 1035                                              CS
# 617                             chemical engineering
# 524                             computer engineering
# 12                              Computer Engineering
# 1059                                         Physics
# ...                                              ...
# 248                                  Bio-engineering
# 767                                       Psychology
# 891                                 Computer Science
# 93                                Law and philosophy
# 796                             computer engineering
#
#      Who is your favorite music artist?  \
# 1035                               Rezz
# 617                                 bts
# 524                        the weekend
# 12                               Hozier
# 1059                            Slant 6
# ...                                 ...
# 248                            Rod Wave
# 767                                 Ed
# 891                         The Weekend
# 93                                  NaN
# 796                             enhypen
#
#      What's your favorite social media app?  \
# 1035                                   VSCO
# 617                               instagram
# 524                               instagram
# 12                                  Twitter
# 1059                                 Reddit
# ...                                     ...
# 248                                  Tiktok
# 767                                  Tiktok
# 891                               Instagram
# 93                                    insta
# 796                               instagram
#
#      What is your favorite game to play (either video game or IRL)?  \
# 1035                            Ghosts in the graveyard
# 617                                   exploding kittens
# 524                                                 uno
# 12                                       Stardew Valley
# 1059                                           Oxenfree
# ...                                                 ...
# 248                                                  2k
# 767                                                Csgo
# 891                                        Ready or Not
# 93                                                  LOL
# 796                                           minecraft
#
#      Where is your dream vacation spot?
# 1035                            Croatia
# 617                               kyoto
# 524                               paris
# 12                               Japan
# 1059                              Japan
# ...                                 ...
# 248                              Sweden
# 767                             Nothing
# 891                               Beach
# 93                                Balli
# 796                               japan
#
# [533 rows x 150 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd.concat([df1_control, df2_control])
control
# Out:
#            Name       Lab When flipping a coin, heads or tails?  \
# 2      Angelina       Y13                                 Tails
# 4        Sneha        Y17                                 Tails
# 8          Eman       Y11                                 Heads
# 13     Kristina       Y33                                 Tails
# 16      Aaliyay       Y30                                 Heads
# ...         ...       ...                                   ...
# 1060   TA Jimmy       Y21                                 Tails
# 1061  TA Kunlun  Y12, Y25                                 Heads
# 1064     Wesley       Y02                                 Tails
# 1068      Bowen       Y25                                 Heads
# 1069   kaicheng       Y11                                 Heads
#
#      Is this your first year at UIUC?  \
# 2                  First Year at UIUC
# 4                  First Year at UIUC
# 8                  First Year at UIUC
# 13                     Not First Year
# 16                 First Year at UIUC
# ...                               ...
# 1060               First Year at UIUC
# 1061               First Year at UIUC
# 1064                   Not First Year
# 1068               First Year at UIUC
# 1069               First Year at UIUC
#
#      Is your favorite ice cream flavor chocolate or vanilla?  \
# 2                                               Vanilla
# 4                                               Vanilla
# 8                                             Chocolate
# 13                                              Vanilla
# 16                                              Vanilla
# ...                                                 ...
# 1060                                          Chocolate
# 1061                                          Chocolate
# 1064                                            Vanilla
# 1068                                          Chocolate
# 1069                                          Chocolate
#
#      Do you like morning or night?  Do you prefer even or odd numbers?  \
# 2                           Morning                               Even
# 4                             Night                               Even
# 8                           Morning                               Even
# 13                            Night                               Even
# 16                            Night                               Even
# ...                             ...                                ...
# 1060                          Night                               Even
# 1061                        Morning                               Even
# 1064                          Night                               Even
# 1068                          Night                                Odd
# 1069                          Night                                Odd
#
#      Do you have a pet? Do you prefer summer or winter?  \
# 2                   Yes                          Summer
# 4                    No                          Summer
# 8                    No                          Summer
# 13                   No                          Winter
# 16                  Yes                          Summer
# ...                 ...                             ...
# 1060                 No                          Summer
# 1061                Yes                          Summer
# 1064                 No                          Summer
# 1068                 No                          Summer
# 1069                 No                          Winter
#
#      Are you a business major?  ...  \
# 2                           No  ...
# 4                          Yes  ...
# 8                           No  ...
# 13                          No  ...
# 16                          No  ...
# ...                        ...  ...
# 1060                        No  ...
# 1061                        No  ...
# 1064                        No  ...
# 1068                        No  ...
# 1069                       Yes  ...
#
#      Besides the US, what country would you like to live in?  \
# 2                                            Hong Kong
# 4                                                Canada
# 8                                                   UAE
# 13                                             Ireland
# 16                                              Canada
# ...                                                 ...
# 1060                                                 UK
# 1061                                              China
# 1064                                              japan
# 1068                                              China
# 1069                                              china
#
#      What is your favorite color? Favorite way to spend your free time?  \
# 2                            Pink                        Watching shows
# 4                           Green                 Reading or crocheting
# 8                             Red                Hang out with friends
# 13                     sage green               Hanging with my friends
# 16                           blue                              on phone
# ...                           ...                                   ...
# 1060                        Black                        Watching shows
# 1061                         blue                                  game
# 1064                         blue                                 sleep
# 1068                       Purple                                 Films
# 1069                         blue                                 sleep
#
#      What genre of music do you like the most?  \
# 2                                          r&b
# 4                                     Pop Rock
# 8                                          R&B
# 13                  alternative and indie folk
# 16                                         rnb
# ...                                        ...
# 1060                                       Pop
# 1061                                      jazz
# 1064                                       pop
# 1068                                      Rocj
# 1069                                     R n B
#
#      If you were an animal, which would you be? / What is your spirit animal?  \
# 2                                                 Tiger
# 4                                               Penguin
# 8                                               Unicorn
# 13                                               kitten
# 16                                                 bird
# ...                                                 ...
# 1060                                              Panda
# 1061                                               egal
# 1064                                         dog/ camel
# 1068                                              Puppy
# 1069                                                dog
#
#      What do you think is the hardest major at UIUC?  \
# 2                             Aerospace engineering
# 4                                   Computer Science
# 8                                            Physics
# 13                                           pre-med
# 16                             aerospace engineering
# ...                                              ...
# 1060                                         Physics
# 1061                                              cs
# 1064                                         english
# 1068                                     Engineering
# 1069                                              ds
#
#      Who is your favorite music artist?  \
# 2                         Ashley Alisha
# 4                       Imagine Dragons
# 8                                   SZA
# 13                        Joni Mitchell
# 16                          Frank Ocean
# ...                                 ...
# 1060                         Kanye West
# 1061                           Coldplay
# 1064                         juice wrld
# 1068                         Kanye West
# 1069                           lil tjay
#
#      What's your favorite social media app?  \
# 2                                     Insta
# 4                                 Instagram
# 8                                 Instagram
# 13                                instagram
# 16                                   tiktok
# ...                                     ...
# 1060                                Discord
# 1061                                 Wechat
# 1064                                youtube
# 1068                                    ins
# 1069                               snapchat
#
#      What is your favorite game to play (either video game or IRL)?  \
# 2                                                   NaN
# 4                                            Beat Saber
# 8                                                  Sims
# 13                                     Dress to Impress
# 16                                               sims 4
# ...                                                 ...
# 1060                                              Poker
# 1061                                          overwatch
# 1064                                        brawl stars
# 1068                                     Stardew Valley
# 1069                                                mma
#
#      Where is your dream vacation spot?
# 2                       Southern France
# 4                                 Italy
# 8                               Greece
# 13                      South of France
# 16                               eurpoe
# ...                                 ...
# 1060                              Japan
# 1061                                 CA
# 1064                              japan
# 1068                              Tokyo
# 1069                            iceland
#
# [534 rows x 150 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."
assert(
  (len(treatment) + len(control) == len(df1) + len(df2)) or 
  (len(treatment) + len(control) == len(df))
), f"Not everyone in the dataset (or everyone who responded to the question being blocked) is included in one of the two groups -- someone is missing! :(\nPeople in treatment group: {len(treatment)}\nPeople in control group: {len(control)}\nTotal in treatment+control group: {len(control) + len(treatment)}\n== vs ==\nTotal people in dataset: {len(df)}\nTotal people with data for blocking: {len(df1) + len(df2)}"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
