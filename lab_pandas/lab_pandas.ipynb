# %% [markdown]
# # Welcome to lab_🐼s!
#
# Last week, you did amazing work setting up your computer to do data science!  Let's now use your computer to do data science for the first time!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant (TA), your Course Assistants (CAs), your lab group, and the professors (Prof. Karle and Prof. Wade), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 0: Your Lab Group!
#
# We find it's best when you're programming with a group of people who you can help out and can help you out!
#
# - A key part of Data Science is being able to **communicate about your work**.  If you are the best programmer in the world, but no one uses your code, then the code you're writing is not getting run.  By learning strong communication skills, you will be able to **explain your code**, and the underlying data science concepts, to everyone -- data scientists and non-scientists alike!
#
# - **Every lab** you will need to complete some parts of the lab **with your group**.  There will be both **"group discussions"** and **"individual reflections"** as part of every lab.

# %% [markdown]
# ## Create Your Group
#
# If you have not done so already, **RIGHT NOW** find *(ideally)* two other people to make a group of **two, three, or four** people.   *(We find groups of three work the best, but you can be a group of two or four -- no solo groups, and no groups of five!*)
#
# - If you're at a group of five, split into a group of two and a group of three.  You can still help each other as a larger group, but the group questions should be answered in your smaller group of 2-4 people.
#
# Once you have your group, **introduce yourselves to each other! :)**

# %% [markdown]
# ## Record Your Group
#
# Since you know Python, edit the following cell to add strings about your group:

# %%
# First, meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Mallory"
ca1_name = "Irene"
ca2_name = "Amelie"
# ca3_name = ""


# As part of your introduction, learn your lab partner's name, major, and
# learn something new about them that you never knew!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "Nina"
partner1_netid = "ninac5@illinois.edu"
partner1_major = "Accounting + Data Science"

partner2_name = "Clement"
partner2_netid = "cyw4@illinois.edu"
partner2_major = "CS"

partner3_name = "Angelina"
partner3_netid = "ay25@illinois.edu"
partner3_major = "Political science"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: 🧑‍🤝‍🧑 Hello Dataset!

# %% [markdown]
# In lecture, we have already begun to explore the "Party Dataset" that you created.  We will continue to use the Party Dataset all semester long, but we want even more datasets -- and we want you to come up with the questions!
#
# In this lab, **you** will come up with questions to ask the entire class for the **"Hello Dataset"**!

# %% [markdown]
# ## Hello Dataset Overview
#
# Over the weekend, your lab homework will be to fill out a class-wide "Hello Survey".  Right now, with your group, you will come up some of the questions that should be on this survey *(and you will do analysis on your questions next week!)*.
#
# With your group, come up with four questions below!  Before you get started, a few notes:
#
# - The survey will be **NOT be anonymous** and the results will be shared with the class to do analysis on, so you should **only ask questions you feel comfortable to share with the class**.
# - **Questions that are inappropriate** for a classroom environment will be thrown out and you won't earn lab credit points for any question we throw out.  (Keep everything at most PG/PG-13.)
# - You are going to submit **one set of questions for your whole group**.  You must decide on the questions together.

# %% [markdown]
# ## Q1: Question with a Binary Response
#
# A question with a **binary response** is a question that has only two answers.  For example:
# - *Do you prefer cats or dogs?*
# - *Were you born in Illinois?*
#
# With your group (you must all decide on a single question together), come up with a question that you think will have **exactly 50%/50%** split between the two binary outcomes.  *(The question that gets closest to 50%/50% will get extra credit!)*

# %% [markdown]
# **What is your binary question?**
#
# *(Are you male or female?)*

# %% [markdown]
# **Why do you think this is a good question?  Write at least two complete sentences on why you believe your question will have a 50%/50% split.**
#
# *(We think this is a good question because each class is such a large sample size that the number of males and females will most likely even out and be close to 50/50. From our observations, there isn't much marginalization in STAT 107 so that confounding factor likely does not exist here.)*

# %% [markdown]
# ## Q2: Question with a Numeric Response
#
# A question with a **numeric response** requires a number for an answer.  For example:
#
# - *What is your height?*
# - *What day were you born?*
#
# With your group (you must all decide on a single question together), come up with a question and a prediction on what you think the most frequent answer will be to your question.

# %% [markdown]
# **What is your numeric question?**
#
# *(How happy are you from a scale of 1-10?)*

# %% [markdown]
# **What do you think the most frequent answer will be?**
#
# *(7)*

# %% [markdown]
# **Why do you think this answer will be the most frequent answer?  Write at least one complete sentence on why you believe that it will be the most frequent answer.**
#
# *(College has just started, so while there is some stress and challenge that prevents the answer from being a complete 10. But then again, because it just started, classes are a little lighter than they usually are right now so everyone's moods are somewhat high.)*

# %% [markdown]
# ## Q3: Question with a (non-numeric) Textual Response
#
# A question with a (non-numeric) **textual response** requires a word or two for an answer.  For example:
#
# - *What is your favorite sport to play?*
# - *What is the location of your favorite trip/vacation?*
#
# With your group (you must all decide on a single question together), come up with a question where at least two members of your group share the same answer.

# %% [markdown]
# **What is your textual response question?**
#
# *(What is your favorite season?)*

# %% [markdown]
# **What is the shared answer between your group?  Do you also share this answer (if not, what's your answer to the question)?**
#
# *(Our group's shared answer is spring, but I don't share this answer. My favorite season is summer!)*

# %% [markdown]
# ## Q4: Open Question
#
# One final question -- no restrictions on the format!  Is there a great question your group discussed that you did not get to use as one of the first three questions but you want to know the class's answer?

# %% [markdown]
# **What is your final question for the whole class?**
#
# *(What is your favorite ice cream flavor?)*

# %% [markdown]
# ## Submit Your Questions to Professors Wade and Karle
#
# Your lab TAs will be grading your lab notebook for your full responses, but we want to make sure to get the survey with your questions out to everyone ASAP!
#
# - Pick one member of your group as the "question submitter".
# - If you're the question submitter, complete this Google Form for your group (requires @illinois.edu login): https://forms.gle/6HQ6MLyEhq7zK36i9
# - Make sure to do this **during your lab section**.

# %% [markdown]
# ## This Weekend: Complete the "Hello Survey"
#
# On Friday evening, after the final lab section, we will post the "Hello Survey" with the questions you (and the entire class) asked.  You will have to complete this before **Monday, Sept. 9** and it will be part of your lab grade.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: Importing the Course Catalog Dataset
#
# In lecture, you learned we will use the `pandas` **library** for working with data.  Libraries are collections of functions and other objects that extend what Python can do by itself.  The `pandas` library is the most widely used library for data science.
#
# To use the `pandas` library, we must **import** it into your notebook.  In every lab, you will need to import the library just like we did in lecture!
#
# In the following cell, replace `...` with the code to import pandas as `pd`:

# %%
# Write the code to import pandas as pd:
import pandas as pd

# %% [markdown]
# In lecture, you saw the "Course Catalog" dataset.  Using the `read_csv` function, load the course catalog dataset.  The URL for this dataset is:
# ```
# https://waf.cs.illinois.edu/discovery/course-catalog.csv
# ```
#
# Remember, URLs passed to `read_csv` are **string** variables, so remember to use **quotation marks**.
#
# > **macOS users**: If you are running macOS, you may get a HTTPS connection security-related error.  If you get this error, there's a solution for you on the Canvas lab overview page!! :)

# %%
# Load the course catalog dataset into a variable named `df`:
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/course-catalog.csv")

# %%
# Look at `df` to confirm that this worked:
df
# Out:
#        Year  Term YearTerm Subject  Number                          Name  \
# 0      2024  Fall  2024-fa     AAS     100  Intro Asian American Studies
# 1      2024  Fall  2024-fa     AAS     100  Intro Asian American Studies
# 2      2024  Fall  2024-fa     AAS     100  Intro Asian American Studies
# 3      2024  Fall  2024-fa     AAS     100  Intro Asian American Studies
# 4      2024  Fall  2024-fa     AAS     100  Intro Asian American Studies
# ...     ...   ...      ...     ...     ...                           ...
# 12985  2024  Fall  2024-fa    WRIT     303          Writing Across Media
# 12986  2024  Fall  2024-fa    WRIT     303          Writing Across Media
# 12987  2024  Fall  2024-fa    YDSH     101           Beginning Yiddish I
# 12988  2024  Fall  2024-fa    YDSH     101           Beginning Yiddish I
# 12989  2024  Fall  2024-fa    YDSH     220           Jewish Storytelling
#
#                                              Description Credit Hours  \
# 0      Interdisciplinary introduction to the basic co...     3 hours.
# 1      Interdisciplinary introduction to the basic co...     3 hours.
# 2      Interdisciplinary introduction to the basic co...     3 hours.
# 3      Interdisciplinary introduction to the basic co...     3 hours.
# 4      Interdisciplinary introduction to the basic co...     3 hours.
# ...                                                  ...          ...
# 12985                    Same as INFO 303. See INFO 303.     3 hours.
# 12986                    Same as INFO 303. See INFO 303.     3 hours.
# 12987  Course develops basic conversational and readi...     4 hours.
# 12988  Course develops basic conversational and readi...     4 hours.
# 12989  Course will introduce the great Jewish storyte...     3 hours.
#
#                                           Section Info  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 12985                  Same as INFO 303. See INFO 303.
# 12986                  Same as INFO 303. See INFO 303.
# 12987                                              NaN
# 12988                                              NaN
# 12989  Same as CWL 221, ENGL 223, JS 220, and REL 220.
#
#                                        Degree Attributes  ... Section Status  \
# 0      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 1      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 2      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 3      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# 4      Social & Beh Sci - Soc Sci, and Cultural Studi...  ...              A
# ...                                                  ...  ...            ...
# 12985                       Advanced Composition course.  ...              A
# 12986                       Advanced Composition course.  ...              A
# 12987                                                NaN  ...              A
# 12988                                                NaN  ...              A
# 12989  Humanities - Lit & Arts, and Cultural Studies ...  ...              A
#
#                 Enrollment Status                   Type Type Code Start Time  \
# 0                            Open  Discussion/Recitation       DIS   09:00 AM
# 1                            Open  Discussion/Recitation       DIS   10:00 AM
# 2                            Open  Discussion/Recitation       DIS   10:00 AM
# 3                            Open  Discussion/Recitation       DIS   11:00 AM
# 4                            Open  Discussion/Recitation       DIS   11:00 AM
# ...                           ...                    ...       ...        ...
# 12985  CrossListOpen (Restricted)                Lecture       LEC   12:30 PM
# 12986                      Closed                Lecture       LEC   02:00 PM
# 12987                        Open                 Online       ONL   09:00 AM
# 12988                        Open                 Online       ONL   09:00 AM
# 12989               CrossListOpen     Lecture-Discussion       LCD   12:30 PM
#
#        End Time Days of Week   Room                       Building  \
# 0      09:50 AM            F    G32  Literatures, Cultures, & Ling
# 1      10:50 AM            F    G32  Literatures, Cultures, & Ling
# 2      10:50 AM            F  106B6               Engineering Hall
# 3      11:50 AM            F  106B6               Engineering Hall
# 4      11:50 AM            F    G36  Literatures, Cultures, & Ling
# ...         ...          ...    ...                            ...
# 12985  01:45 PM           TR    428                         Armory
# 12986  03:15 PM           TR   1028                   Lincoln Hall
# 12987  10:00 AM            F    NaN                            NaN
# 12988  10:30 AM           MW    NaN                            NaN
# 12989  01:50 PM           TR    310              David Kinley Hall
#
#                 Instructors
# 0         Siglos, D;Wang, Y
# 1         Siglos, D;Wang, Y
# 2      Charity, H;Siglos, D
# 3      Charity, H;Siglos, D
# 4          Kim, G;Siglos, D
# ...                     ...
# 12985                   NaN
# 12986                   NaN
# 12987             Butler, D
# 12988             Butler, D
# 12989           Grossman, R
#
# [12990 rows x 27 columns]

# %% [markdown]
# ## 🔬 Test Case Checkpoint 🔬
#
# Throughout the lab, we will have "checkpoints" at key points.  Most checkpoints will include **test cases** that verify that your notebook appears to be correct.
#
# - The test cases are **NOT** a guarantee that everything is perfect, but we try our very best to catch any common mistakes you might make!
# - If you see `AssertionError` error message when running the test case, we provide a helpful hint on what may not be correct.
# - If you see a party popper emoji and a message that all tests pass, you passed the checkpoint!
# - **Checkpoints** are a good time to check with your group to make everyone gets to the checkpoint together!

# %%
## == CHECKPOINT TEST CASES for Part 1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "Did you define a variable called df?"
assert( len(df) == 12990 ), "It looks like you did not import the correct dataset?"


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: STAT / CS / IS Majors
#
# Data Science DISCOVERY is a unique course that is cross-listed across three departments: Statistics, Computer Science, and Information Sciences.  Let's explore courses from all three of those subjects!

# %% [markdown]
# ### Puzzle 3.1
#
# Select only the rows that have a `Subject` of `STAT`.  Assign this to the variable name `df_STAT` instead of the usual `df`.
# - Make sure your result contains only statistics courses!

# %%
df_STAT = df[ df.Subject == "STAT"]
df_STAT
# Out:
#        Year  Term YearTerm Subject  Number                           Name  \
# 12180  2024  Fall  2024-fa    STAT     100                     Statistics
# 12181  2024  Fall  2024-fa    STAT     100                     Statistics
# 12182  2024  Fall  2024-fa    STAT     100                     Statistics
# 12183  2024  Fall  2024-fa    STAT     107         Data Science Discovery
# 12184  2024  Fall  2024-fa    STAT     107         Data Science Discovery
# ...     ...   ...      ...     ...     ...                            ...
# 12351  2024  Fall  2024-fa    STAT     571          Multivariate Analysis
# 12352  2024  Fall  2024-fa    STAT     590  Individual Study and Research
# 12353  2024  Fall  2024-fa    STAT     593                STAT Internship
# 12354  2024  Fall  2024-fa    STAT     593                STAT Internship
# 12355  2024  Fall  2024-fa    STAT     599                Thesis Research
#
#                                              Description    Credit Hours  \
# 12180  First course in probability and statistics at ...        3 hours.
# 12181  First course in probability and statistics at ...        3 hours.
# 12182  First course in probability and statistics at ...        3 hours.
# 12183  Data Science Discovery is the intersection of ...        4 hours.
# 12184  Data Science Discovery is the intersection of ...        4 hours.
# ...                                                  ...             ...
# 12351  Inference in multivariate statistical populati...        4 hours.
# 12352  Directed reading and research. Approved for le...   0 TO 8 hours.
# 12353  Supervised, off-campus experience in a field i...   0 TO 8 hours.
# 12354  Supervised, off-campus experience in a field i...   0 TO 8 hours.
# 12355  Approved for S/U grading only. May be repeated...  0 TO 16 hours.
#
#                                             Section Info  \
# 12180  Credit is not given for both STAT 100 and any ...
# 12181  Credit is not given for both STAT 100 and any ...
# 12182  Credit is not given for both STAT 100 and any ...
# 12183                         Same as CS 107 and IS 107.
# 12184                         Same as CS 107 and IS 107.
# ...                                                  ...
# 12351  Prerequisite: STAT 410 and MATH 415, or consen...
# 12352  Approved for letter and S/U grading. May be re...
# 12353  Approved for letter and S/U grading. Prerequis...
# 12354  Approved for letter and S/U grading. Prerequis...
# 12355  Approved for S/U grading only. May be repeated...
#
#                       Degree Attributes  ... Section Status  \
# 12180  Quantitative Reasoning I course.  ...              A
# 12181  Quantitative Reasoning I course.  ...              A
# 12182  Quantitative Reasoning I course.  ...              A
# 12183  Quantitative Reasoning I course.  ...              A
# 12184  Quantitative Reasoning I course.  ...              A
# ...                                 ...  ...            ...
# 12351                               NaN  ...              A
# 12352                               NaN  ...              A
# 12353                               NaN  ...              A
# 12354                               NaN  ...              A
# 12355                               NaN  ...              A
#
#        Enrollment Status                Type Type Code Start Time  End Time  \
# 12180             Closed  Lecture-Discussion       LCD   12:00 PM  12:50 PM
# 12181  Open (Restricted)  Lecture-Discussion       LCD   03:00 PM  03:50 PM
# 12182             Closed              Online       ONL   ARRANGED       NaN
# 12183             Closed             Lecture       LEC   11:00 AM  11:50 AM
# 12184             Closed             Lecture       LEC   09:00 AM  09:50 AM
# ...                  ...                 ...       ...        ...       ...
# 12351  Open (Restricted)  Lecture-Discussion       LCD   03:00 PM  03:50 PM
# 12352  Open (Restricted)   Independent Study       IND   ARRANGED       NaN
# 12353  Open (Restricted)          Internship       INT   ARRANGED       NaN
# 12354  Open (Restricted)          Internship       INT   ARRANGED       NaN
# 12355  Open (Restricted)   Independent Study       IND   ARRANGED       NaN
#
#       Days of Week   Room               Building  \
# 12180          MWF  THEAT           Lincoln Hall
# 12181          MWF    AUD  Foellinger Auditorium
# 12182          NaN    NaN                    NaN
# 12183          MWF  THEAT           Lincoln Hall
# 12184          MWF    AUD  Foellinger Auditorium
# ...            ...    ...                    ...
# 12351          MWF  106B8       Engineering Hall
# 12352          NaN    NaN                    NaN
# 12353          NaN    NaN                    NaN
# 12354          NaN    NaN                    NaN
# 12355          NaN    NaN                    NaN
#
#                                              Instructors
# 12180                                        Flanagan, K
# 12181                                             Rao, V
# 12182                                             Rao, V
# 12183                  Fagen-Ulmschneider, W;Flanagan, K
# 12184                  Fagen-Ulmschneider, W;Flanagan, K
# ...                                                  ...
# 12351                                            Park, T
# 12352                                                NaN
# 12353  Chronopoulou, A;Glosemeyer, D;Lee, H;Shao, X;U...
# 12354  Chronopoulou, A;Glosemeyer, D;Lee, H;Shao, X;U...
# 12355                                                NaN
#
# [176 rows x 27 columns]

# %% [markdown]
# ### Puzzle 3.2
#
# Select only the rows that have a `Subject` of `CS`.  Assign this to the variable name `df_CS` instead of the usual `df`.
# - Make sure your result contains only computer science courses!

# %%
df_CS = df[ df.Subject == "CS"]
df_CS
# Out:
#       Year  Term YearTerm Subject  Number                              Name  \
# 3298  2024  Fall  2024-fa      CS     100      Computer Science Orientation
# 3299  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3300  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3301  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3302  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# ...    ...   ...      ...     ...     ...                               ...
# 3768  2024  Fall  2024-fa      CS     598                    Special Topics
# 3769  2024  Fall  2024-fa      CS     598                    Special Topics
# 3770  2024  Fall  2024-fa      CS     598                    Special Topics
# 3771  2024  Fall  2024-fa      CS     598                    Special Topics
# 3772  2024  Fall  2024-fa      CS     599                   Thesis Research
#
#                                             Description    Credit Hours  \
# 3298  Introduction to Computer Science as a field an...        1 hours.
# 3299  Fundamental principles, concepts, and methods ...        3 hours.
# 3300  Fundamental principles, concepts, and methods ...        3 hours.
# 3301  Fundamental principles, concepts, and methods ...        3 hours.
# 3302  Fundamental principles, concepts, and methods ...        3 hours.
# ...                                                 ...             ...
# 3768  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3769  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3770  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3771  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3772    Approved for S/U grading only. May be repeated.  0 TO 16 hours.
#
#                                            Section Info  \
# 3298                                                NaN
# 3299  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3300  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3301  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3302  Prerequisite: One of MATH 220 or MATH 221 or M...
# ...                                                 ...
# 3768  May be repeated in the same or separate terms ...
# 3769  May be repeated in the same or separate terms ...
# 3770  May be repeated in the same or separate terms ...
# 3771  May be repeated in the same or separate terms ...
# 3772    Approved for S/U grading only. May be repeated.
#
#                       Degree Attributes  ... Section Status  \
# 3298                                NaN  ...              A
# 3299  Quantitative Reasoning II course.  ...              A
# 3300  Quantitative Reasoning II course.  ...              A
# 3301  Quantitative Reasoning II course.  ...              A
# 3302  Quantitative Reasoning II course.  ...              A
# ...                                 ...  ...            ...
# 3768                                NaN  ...              A
# 3769                                NaN  ...              A
# 3770                                NaN  ...              A
# 3771                                NaN  ...              A
# 3772                                NaN  ...              A
#
#       Enrollment Status                   Type Type Code Start Time  End Time  \
# 3298  Open (Restricted)                Lecture       LEC   03:00 PM  03:50 PM
# 3299  Open (Restricted)     Lecture-Discussion       LCD   10:00 AM  10:50 AM
# 3300               Open  Laboratory-Discussion       LBD   01:00 PM  02:50 PM
# 3301               Open  Laboratory-Discussion       LBD   03:00 PM  04:50 PM
# 3302               Open  Laboratory-Discussion       LBD   05:00 PM  06:50 PM
# ...                 ...                    ...       ...        ...       ...
# 3768  Open (Restricted)     Lecture-Discussion       S10   09:30 AM  10:45 AM
# 3769             Closed     Lecture-Discussion        S1   11:00 AM  12:15 PM
# 3770  Open (Restricted)     Lecture-Discussion       S16   12:30 PM  01:45 PM
# 3771             Closed     Lecture-Discussion        S8   12:30 PM  01:45 PM
# 3772             Closed      Independent Study       IND   ARRANGED       NaN
#
#      Days of Week   Room                       Building          Instructors
# 3298            F  THEAT                   Lincoln Hall           Shaffer, E
# 3299           MW    AUD          Foellinger Auditorium  Beckman, M;Silva, M
# 3300            M   1038  Campus Instructional Facility           Beckman, M
# 3301            M   1038  Campus Instructional Facility           Beckman, M
# 3302            M   1038  Campus Instructional Facility           Beckman, M
# ...           ...    ...                            ...                  ...
# 3768           TR   1214     Siebel Center for Comp Sci            August, T
# 3769           TR   2406     Siebel Center for Comp Sci             Zhang, T
# 3770           WF   1214     Siebel Center for Comp Sci           Vasisht, D
# 3771           WF   1304     Siebel Center for Comp Sci               You, J
# 3772          NaN    NaN                            NaN                  NaN
#
# [475 rows x 27 columns]

# %% [markdown]
# ### Puzzle 3.3
#
# Select only the rows that have a `Subject` of `IS`.  Assign this to the variable name `df_IS` instead of the usual `df`.
# - Make sure your result contains only information science courses!

# %%
df_IS = df[ df.Subject == "IS"]
df_IS
# Out:
#       Year  Term YearTerm Subject  Number  \
# 7003  2024  Fall  2024-fa      IS     100
# 7004  2024  Fall  2024-fa      IS     100
# 7005  2024  Fall  2024-fa      IS     100
# 7006  2024  Fall  2024-fa      IS     100
# 7007  2024  Fall  2024-fa      IS     100
# ...    ...   ...      ...     ...     ...
# 7303  2024  Fall  2024-fa      IS     599
# 7304  2024  Fall  2024-fa      IS     599
# 7305  2024  Fall  2024-fa      IS     599
# 7306  2024  Fall  2024-fa      IS     599
# 7307  2024  Fall  2024-fa      IS     599
#
#                                                   Name  \
# 7003  Exploring the iSchool with a Human-Centered Lens
# 7004  Exploring the iSchool with a Human-Centered Lens
# 7005  Exploring the iSchool with a Human-Centered Lens
# 7006  Exploring the iSchool with a Human-Centered Lens
# 7007  Exploring the iSchool with a Human-Centered Lens
# ...                                                ...
# 7303                                   Thesis Research
# 7304                                   Thesis Research
# 7305                                   Thesis Research
# 7306                                   Thesis Research
# 7307                                   Thesis Research
#
#                                             Description    Credit Hours  \
# 7003  This course introduces students to the School ...        1 hours.
# 7004  This course introduces students to the School ...        1 hours.
# 7005  This course introduces students to the School ...        1 hours.
# 7006  This course introduces students to the School ...        1 hours.
# 7007  This course introduces students to the School ...        1 hours.
# ...                                                 ...             ...
# 7303  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 7304  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 7305  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 7306  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 7307  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info Degree Attributes  \
# 7003  Prerequisite: Restricted to Majors Only; First...               NaN
# 7004  Prerequisite: Restricted to Majors Only; First...               NaN
# 7005  Prerequisite: Restricted to Majors Only; First...               NaN
# 7006  Prerequisite: Restricted to Majors Only; First...               NaN
# 7007  Prerequisite: Restricted to Majors Only; First...               NaN
# ...                                                 ...               ...
# 7303  0 to 16 graduate hours. No professional credit...               NaN
# 7304  0 to 16 graduate hours. No professional credit...               NaN
# 7305  0 to 16 graduate hours. No professional credit...               NaN
# 7306  0 to 16 graduate hours. No professional credit...               NaN
# 7307  0 to 16 graduate hours. No professional credit...               NaN
#
#       ... Section Status  Enrollment Status                Type Type Code  \
# 7003  ...              A             Closed  Lecture-Discussion       LCD
# 7004  ...              A             Closed  Lecture-Discussion       LCD
# 7005  ...              A             Closed  Lecture-Discussion       LCD
# 7006  ...              A             Closed  Lecture-Discussion       LCD
# 7007  ...              A             Closed  Lecture-Discussion       LCD
# ...   ...            ...                ...                 ...       ...
# 7303  ...              A               Open   Independent Study       IND
# 7304  ...              A               Open   Independent Study       IND
# 7305  ...              A               Open   Independent Study       IND
# 7306  ...              A               Open   Independent Study       IND
# 7307  ...              A               Open   Independent Study       IND
#
#      Start Time  End Time Days of Week Room                        Building  \
# 7003   01:00 PM  01:50 PM            W  126  Grad Sch of Lib & Info Science
# 7004   01:00 PM  01:50 PM            W  126  Grad Sch of Lib & Info Science
# 7005   10:00 AM  10:50 AM            M  126  Grad Sch of Lib & Info Science
# 7006   10:00 AM  10:50 AM            M  126  Grad Sch of Lib & Info Science
# 7007   02:00 PM  02:50 PM            R  126  Grad Sch of Lib & Info Science
# ...         ...       ...          ...  ...                             ...
# 7303   ARRANGED       NaN          NaN  NaN                             NaN
# 7304   ARRANGED       NaN          NaN  NaN                             NaN
# 7305   ARRANGED       NaN          NaN  NaN                             NaN
# 7306   ARRANGED       NaN          NaN  NaN                             NaN
# 7307   ARRANGED       NaN          NaN  NaN                             NaN
#
#              Instructors
# 7003            Kittl, K
# 7004            Kittl, K
# 7005           Lehman, L
# 7006           Lehman, L
# 7007  Kittl, K;Lehman, L
# ...                  ...
# 7303           Torvik, V
# 7304        Underwood, W
# 7305            Huang, Y
# 7306             Wang, Y
# 7307          LeBlanc, Z
#
# [305 rows x 27 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES for Part 3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df_CS' in vars() ), "Make certain to name the CS courses df_CS."
assert( 'df_STAT' in vars() ), "Make certain to name the STAT courses df_STAT."
assert( 'df_IS' in vars() ), "Make certain to name the IS courses df_IS."
assert( len(df_STAT[df_STAT.Subject != "STAT"] ) == 0 ), "It looks like you did not subset df_STAT to only STAT courses."
assert( len(df_CS[df_CS.Subject != "CS"] ) == 0 ), "It looks like you did not subset df_CS to only CS courses."
assert( len(df_IS[df_IS.Subject != "IS"] ) == 0 ), "It looks like you did not subset df_IS to only IS courses."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.4
#
# Looking at the output of the DataFrames for STAT, CS, and IS above, which subject offers the **fewest** course sections?  The **most** course sections?
#
# Be very clear on which specific subject has the **fewest** sections and which specific subject has the **most** sections by writing a complete sentence to answer this question.

# %% [markdown]
# *(STAT offers 174 course sections, so it has the fewest course sections. CS offers 473 course sections, so it has the most course sections.)*

# %% [markdown]
# ### Puzzle 3.5
#
# Looking at the output of the DataFrames for STAT, CS, and IS above, which subject has the highest course number (for example: "STAT 107" course number is "107")?  Is there something similar about all of the highest numbered courses?  Write about what you observed!

# %% [markdown]
# *(All subjects have course numbers that go to 599, which is individual study and research for a thesis.)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 4: Your Major

# %% [markdown]
# In this part, you will be exploring **your major** using the Course Catalog dataset.
#
# - Use the primary subject of your **current major** (or, if you're undeclared, your intended major) for this section.
# - Your answers will be different than the rest of your group!

# %% [markdown]
# ### Puzzle 4.1:
#
# Select only the rows that have a `Subject` of your current/intended major.  Assign this to the variable name `mydf` instead of `df`:

# %%
mydf = df[ df.Subject == "CS"]
mydf
# Out:
#       Year  Term YearTerm Subject  Number                              Name  \
# 3298  2024  Fall  2024-fa      CS     100      Computer Science Orientation
# 3299  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3300  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3301  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3302  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# ...    ...   ...      ...     ...     ...                               ...
# 3768  2024  Fall  2024-fa      CS     598                    Special Topics
# 3769  2024  Fall  2024-fa      CS     598                    Special Topics
# 3770  2024  Fall  2024-fa      CS     598                    Special Topics
# 3771  2024  Fall  2024-fa      CS     598                    Special Topics
# 3772  2024  Fall  2024-fa      CS     599                   Thesis Research
#
#                                             Description    Credit Hours  \
# 3298  Introduction to Computer Science as a field an...        1 hours.
# 3299  Fundamental principles, concepts, and methods ...        3 hours.
# 3300  Fundamental principles, concepts, and methods ...        3 hours.
# 3301  Fundamental principles, concepts, and methods ...        3 hours.
# 3302  Fundamental principles, concepts, and methods ...        3 hours.
# ...                                                 ...             ...
# 3768  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3769  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3770  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3771  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3772    Approved for S/U grading only. May be repeated.  0 TO 16 hours.
#
#                                            Section Info  \
# 3298                                                NaN
# 3299  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3300  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3301  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3302  Prerequisite: One of MATH 220 or MATH 221 or M...
# ...                                                 ...
# 3768  May be repeated in the same or separate terms ...
# 3769  May be repeated in the same or separate terms ...
# 3770  May be repeated in the same or separate terms ...
# 3771  May be repeated in the same or separate terms ...
# 3772    Approved for S/U grading only. May be repeated.
#
#                       Degree Attributes  ... Section Status  \
# 3298                                NaN  ...              A
# 3299  Quantitative Reasoning II course.  ...              A
# 3300  Quantitative Reasoning II course.  ...              A
# 3301  Quantitative Reasoning II course.  ...              A
# 3302  Quantitative Reasoning II course.  ...              A
# ...                                 ...  ...            ...
# 3768                                NaN  ...              A
# 3769                                NaN  ...              A
# 3770                                NaN  ...              A
# 3771                                NaN  ...              A
# 3772                                NaN  ...              A
#
#       Enrollment Status                   Type Type Code Start Time  End Time  \
# 3298  Open (Restricted)                Lecture       LEC   03:00 PM  03:50 PM
# 3299  Open (Restricted)     Lecture-Discussion       LCD   10:00 AM  10:50 AM
# 3300               Open  Laboratory-Discussion       LBD   01:00 PM  02:50 PM
# 3301               Open  Laboratory-Discussion       LBD   03:00 PM  04:50 PM
# 3302               Open  Laboratory-Discussion       LBD   05:00 PM  06:50 PM
# ...                 ...                    ...       ...        ...       ...
# 3768  Open (Restricted)     Lecture-Discussion       S10   09:30 AM  10:45 AM
# 3769             Closed     Lecture-Discussion        S1   11:00 AM  12:15 PM
# 3770  Open (Restricted)     Lecture-Discussion       S16   12:30 PM  01:45 PM
# 3771             Closed     Lecture-Discussion        S8   12:30 PM  01:45 PM
# 3772             Closed      Independent Study       IND   ARRANGED       NaN
#
#      Days of Week   Room                       Building          Instructors
# 3298            F  THEAT                   Lincoln Hall           Shaffer, E
# 3299           MW    AUD          Foellinger Auditorium  Beckman, M;Silva, M
# 3300            M   1038  Campus Instructional Facility           Beckman, M
# 3301            M   1038  Campus Instructional Facility           Beckman, M
# 3302            M   1038  Campus Instructional Facility           Beckman, M
# ...           ...    ...                            ...                  ...
# 3768           TR   1214     Siebel Center for Comp Sci            August, T
# 3769           TR   2406     Siebel Center for Comp Sci             Zhang, T
# 3770           WF   1214     Siebel Center for Comp Sci           Vasisht, D
# 3771           WF   1304     Siebel Center for Comp Sci               You, J
# 3772          NaN    NaN                            NaN                  NaN
#
# [475 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.2:
#
# Select **five random course sections** from your major, using `mydf` and pandas functions:

# %%
...

mydf = df[ df.Subject == "CS"]
mydf.sample(n=5)
# Out:
#       Year  Term YearTerm Subject  Number  \
# 3483  2024  Fall  2024-fa      CS     374
# 3539  2024  Fall  2024-fa      CS     418
# 3543  2024  Fall  2024-fa      CS     421
# 3563  2024  Fall  2024-fa      CS     425
# 3444  2024  Fall  2024-fa      CS     307
#
#                                                    Name  \
# 3483  Introduction to Algorithms &amp; Models of Com...
# 3539                      Interactive Computer Graphics
# 3543              Programming Languages &amp; Compilers
# 3563                                Distributed Systems
# 3444              Modeling and Learning in Data Science
#
#                                             Description   Credit Hours  \
# 3483  Analysis of algorithms, major paradigms of alg...       4 hours.
# 3539  Basic mathematical tools and computational tec...  3 OR 4 hours.
# 3543  Structure of programming languages and their i...  3 OR 4 hours.
# 3563  Protocols, specification techniques, global st...  3 OR 4 hours.
# 3444  Introduction to the use of classical approache...       4 hours.
#
#                                            Section Info Degree Attributes  \
# 3483  Same as ECE 374. Prerequisite: One of CS 173, ...               NaN
# 3539  Same as CSE 427. 3 undergraduate hours. 3 or 4...               NaN
# 3543  3 undergraduate hours. 3 or 4 graduate hours. ...               NaN
# 3563  Same as ECE 428. 3 or 4 undergraduate hours. 3...               NaN
# 3444  Prerequisite: STAT 207; one of MATH 225, MATH ...               NaN
#
#       ... Section Status           Enrollment Status                   Type  \
# 3483  ...              A                      Closed                Lecture
# 3539  ...              A  CrossListOpen (Restricted)                 Online
# 3543  ...              A  CrossListOpen (Restricted)     Lecture-Discussion
# 3563  ...              A                      Closed     Lecture-Discussion
# 3444  ...              A                      Closed  Discussion/Recitation
#
#      Type Code Start Time  End Time Days of Week       Room  \
# 3483       LEC   12:30 PM  01:45 PM           TR  0027/1025
# 3539       ONL   ARRANGED       NaN          NaN        NaN
# 3543       LCD   12:30 PM  01:45 PM            R        ARR
# 3563       LCD   02:00 PM  03:15 PM           TR  0027/1025
# 3444       DIS   09:30 AM  10:45 AM            F       1320
#
#                            Building          Instructors
# 3483  Campus Instructional Facility   Abraham, I;Kani, N
# 3539                            NaN      Tychonievich, L
# 3543                  Illini Center        Misailovic, S
# 3563  Campus Instructional Facility  Ganesan, A;Gupta, I
# 3444    Digital Computer Laboratory           Dalpiaz, D
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.3:
#
# Select **the seven course sections with the smallest course number** from your major:

# %%
mydf = df[ df.Subject == "CS"]
mydf.nsmallest(7, 'Number')
# Out:
#       Year  Term YearTerm Subject  Number                              Name  \
# 3298  2024  Fall  2024-fa      CS     100      Computer Science Orientation
# 3299  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3300  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3301  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3302  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3303  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
# 3304  2024  Fall  2024-fa      CS     101  Intro Computing: Engrg &amp; Sci
#
#                                             Description Credit Hours  \
# 3298  Introduction to Computer Science as a field an...     1 hours.
# 3299  Fundamental principles, concepts, and methods ...     3 hours.
# 3300  Fundamental principles, concepts, and methods ...     3 hours.
# 3301  Fundamental principles, concepts, and methods ...     3 hours.
# 3302  Fundamental principles, concepts, and methods ...     3 hours.
# 3303  Fundamental principles, concepts, and methods ...     3 hours.
# 3304  Fundamental principles, concepts, and methods ...     3 hours.
#
#                                            Section Info  \
# 3298                                                NaN
# 3299  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3300  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3301  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3302  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3303  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3304  Prerequisite: One of MATH 220 or MATH 221 or M...
#
#                       Degree Attributes  ... Section Status  \
# 3298                                NaN  ...              A
# 3299  Quantitative Reasoning II course.  ...              A
# 3300  Quantitative Reasoning II course.  ...              A
# 3301  Quantitative Reasoning II course.  ...              A
# 3302  Quantitative Reasoning II course.  ...              A
# 3303  Quantitative Reasoning II course.  ...              A
# 3304  Quantitative Reasoning II course.  ...              A
#
#       Enrollment Status                   Type Type Code Start Time  End Time  \
# 3298  Open (Restricted)                Lecture       LEC   03:00 PM  03:50 PM
# 3299  Open (Restricted)     Lecture-Discussion       LCD   10:00 AM  10:50 AM
# 3300               Open  Laboratory-Discussion       LBD   01:00 PM  02:50 PM
# 3301               Open  Laboratory-Discussion       LBD   03:00 PM  04:50 PM
# 3302               Open  Laboratory-Discussion       LBD   05:00 PM  06:50 PM
# 3303               Open  Laboratory-Discussion       LBD   09:00 AM  10:50 AM
# 3304             Closed  Laboratory-Discussion       LBD   11:00 AM  12:50 PM
#
#      Days of Week   Room                       Building          Instructors
# 3298            F  THEAT                   Lincoln Hall           Shaffer, E
# 3299           MW    AUD          Foellinger Auditorium  Beckman, M;Silva, M
# 3300            M   1038  Campus Instructional Facility           Beckman, M
# 3301            M   1038  Campus Instructional Facility           Beckman, M
# 3302            M   1038  Campus Instructional Facility           Beckman, M
# 3303            T   1038  Campus Instructional Facility           Beckman, M
# 3304            T   2036  Campus Instructional Facility           Beckman, M
#
# [7 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.4:
#
# Select **the nine course sections with the highest course number** from your major:

# %%
mydf = df[ df.Subject == "CS"]
mydf.nlargest(9, 'Number')
# Out:
#       Year  Term YearTerm Subject  Number             Name  \
# 3772  2024  Fall  2024-fa      CS     599  Thesis Research
# 3741  2024  Fall  2024-fa      CS     598   Special Topics
# 3742  2024  Fall  2024-fa      CS     598   Special Topics
# 3743  2024  Fall  2024-fa      CS     598   Special Topics
# 3744  2024  Fall  2024-fa      CS     598   Special Topics
# 3745  2024  Fall  2024-fa      CS     598   Special Topics
# 3746  2024  Fall  2024-fa      CS     598   Special Topics
# 3747  2024  Fall  2024-fa      CS     598   Special Topics
# 3748  2024  Fall  2024-fa      CS     598   Special Topics
#
#                                             Description    Credit Hours  \
# 3772    Approved for S/U grading only. May be repeated.  0 TO 16 hours.
# 3741  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3742  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3743  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3744  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3745  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3746  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3747  Subject offerings of new and developing areas ...   2 TO 4 hours.
# 3748  Subject offerings of new and developing areas ...   2 TO 4 hours.
#
#                                            Section Info Degree Attributes  \
# 3772    Approved for S/U grading only. May be repeated.               NaN
# 3741  May be repeated in the same or separate terms ...               NaN
# 3742  May be repeated in the same or separate terms ...               NaN
# 3743  May be repeated in the same or separate terms ...               NaN
# 3744  May be repeated in the same or separate terms ...               NaN
# 3745  May be repeated in the same or separate terms ...               NaN
# 3746  May be repeated in the same or separate terms ...               NaN
# 3747  May be repeated in the same or separate terms ...               NaN
# 3748  May be repeated in the same or separate terms ...               NaN
#
#       ... Section Status  Enrollment Status                Type Type Code  \
# 3772  ...              A             Closed   Independent Study       IND
# 3741  ...              A  Open (Restricted)  Lecture-Discussion       S13
# 3742  ...              A             Closed  Lecture-Discussion        S4
# 3743  ...              A             Closed              Online        E1
# 3744  ...              A  Open (Restricted)              Online        E4
# 3745  ...              A  Open (Restricted)  Lecture-Discussion        S1
# 3746  ...              A  Open (Restricted)  Lecture-Discussion       S12
# 3747  ...              A             Closed  Lecture-Discussion        S6
# 3748  ...              A  Open (Restricted)  Lecture-Discussion       S18
#
#      Start Time  End Time Days of Week  Room                       Building  \
# 3772   ARRANGED       NaN          NaN   NaN                            NaN
# 3741   12:30 PM  01:45 PM           TR  2233             Everitt Laboratory
# 3742   12:30 PM  01:45 PM           WF  1302     Siebel Center for Comp Sci
# 3743   ARRANGED       NaN          NaN   NaN                            NaN
# 3744   ARRANGED       NaN          NaN   NaN                            NaN
# 3745   11:00 AM  12:15 PM           TR   216     Siebel Center for Comp Sci
# 3746   03:30 PM  04:45 PM           TR  3025  Campus Instructional Facility
# 3747   02:00 PM  03:15 PM           WF  1302     Siebel Center for Comp Sci
# 3748   02:00 PM  03:15 PM           TR  1214     Siebel Center for Comp Sci
#
#                      Instructors
# 3772                         NaN
# 3741                    Bates, A
# 3742                    Zhang, M
# 3743                   Willis, C
# 3744                  Farivar, R
# 3745                  Chekuri, C
# 3746  Chandrasekharan, E;Saha, K
# 3747              Hakkani Tur, D
# 3748                Solomonik, E
#
# [9 rows x 27 columns]

# %% [markdown]
# ### Puzzle 4.5:
#
# Select **a random sample of 10% of the course sections** from your major:

# %%
mydf = df[ df.Subject == "CS"]
mydf.sample(frac=0.1)
# Out:
#       Year  Term YearTerm Subject  Number  \
# 3388  2024  Fall  2024-fa      CS     128
# 3705  2024  Fall  2024-fa      CS     538
# 3368  2024  Fall  2024-fa      CS     107
# 3635  2024  Fall  2024-fa      CS     465
# 3697  2024  Fall  2024-fa      CS     499
# 3702  2024  Fall  2024-fa      CS     521
# 3346  2024  Fall  2024-fa      CS     107
# 3583  2024  Fall  2024-fa      CS     438
# 3472  2024  Fall  2024-fa      CS     374
# 3389  2024  Fall  2024-fa      CS     128
# 3451  2024  Fall  2024-fa      CS     341
# 3712  2024  Fall  2024-fa      CS     547
# 3606  2024  Fall  2024-fa      CS     450
# 3442  2024  Fall  2024-fa      CS     233
# 3344  2024  Fall  2024-fa      CS     107
# 3730  2024  Fall  2024-fa      CS     591
# 3650  2024  Fall  2024-fa      CS     473
# 3686  2024  Fall  2024-fa      CS     497
# 3717  2024  Fall  2024-fa      CS     571
# 3545  2024  Fall  2024-fa      CS     421
# 3662  2024  Fall  2024-fa      CS     475
# 3335  2024  Fall  2024-fa      CS     107
# 3317  2024  Fall  2024-fa      CS     101
# 3558  2024  Fall  2024-fa      CS     425
# 3750  2024  Fall  2024-fa      CS     598
# 3685  2024  Fall  2024-fa      CS     492
# 3578  2024  Fall  2024-fa      CS     437
# 3477  2024  Fall  2024-fa      CS     374
# 3365  2024  Fall  2024-fa      CS     107
# 3324  2024  Fall  2024-fa      CS     105
# 3595  2024  Fall  2024-fa      CS     444
# 3612  2024  Fall  2024-fa      CS     460
# 3732  2024  Fall  2024-fa      CS     591
# 3531  2024  Fall  2024-fa      CS     412
# 3396  2024  Fall  2024-fa      CS     128
# 3674  2024  Fall  2024-fa      CS     483
# 3753  2024  Fall  2024-fa      CS     598
# 3332  2024  Fall  2024-fa      CS     107
# 3304  2024  Fall  2024-fa      CS     101
# 3468  2024  Fall  2024-fa      CS     361
# 3767  2024  Fall  2024-fa      CS     598
# 3307  2024  Fall  2024-fa      CS     101
# 3765  2024  Fall  2024-fa      CS     598
# 3390  2024  Fall  2024-fa      CS     128
# 3380  2024  Fall  2024-fa      CS     124
# 3617  2024  Fall  2024-fa      CS     461
# 3445  2024  Fall  2024-fa      CS     307
# 3450  2024  Fall  2024-fa      CS     341
#
#                                                    Name  \
# 3388                Introduction to Computer Science II
# 3705                         Advanced Computer Networks
# 3368                             Data Science Discovery
# 3635                              User Interface Design
# 3697                                      Senior Thesis
# 3702             Advanced Topics in Programming Systems
# 3346                             Data Science Discovery
# 3583                             Communication Networks
# 3472  Introduction to Algorithms &amp; Models of Com...
# 3389                Introduction to Computer Science II
# 3451                                 System Programming
# 3712                                      Deep Learning
# 3606                                 Numerical Analysis
# 3442                              Computer Architecture
# 3344                             Data Science Discovery
# 3730                                   Advanced Seminar
# 3650                                         Algorithms
# 3686                                    CS Team Project
# 3717                          Combinatorial Mathematics
# 3545              Programming Languages &amp; Compilers
# 3662                       Formal Models of Computation
# 3335                             Data Science Discovery
# 3317                   Intro Computing: Engrg &amp; Sci
# 3558                                Distributed Systems
# 3750                                     Special Topics
# 3685                                   Senior Project I
# 3578                       Topics in Internet of Things
# 3477  Introduction to Algorithms &amp; Models of Com...
# 3365                             Data Science Discovery
# 3324                          Intro Computing: Non-Tech
# 3595                  Deep Learning for Computer Vision
# 3612                                Security Laboratory
# 3732                                   Advanced Seminar
# 3531                        Introduction to Data Mining
# 3396                Introduction to Computer Science II
# 3674                       Applied Parallel Programming
# 3753                                     Special Topics
# 3332                             Data Science Discovery
# 3304                   Intro Computing: Engrg &amp; Sci
# 3468  Probability &amp; Statistics for Computer Science
# 3767                                     Special Topics
# 3307                   Intro Computing: Engrg &amp; Sci
# 3765                                     Special Topics
# 3390                Introduction to Computer Science II
# 3380                 Introduction to Computer Science I
# 3617                                Computer Security I
# 3445              Modeling and Learning in Data Science
# 3450                                 System Programming
#
#                                             Description   Credit Hours  \
# 3388  Continuation of CS 124. More advanced concepts...       3 hours.
# 3705  Advanced concepts in computer networks, includ...       4 hours.
# 3368         Same as IS 107 and STAT 107. See STAT 107.       4 hours.
# 3635  A project-focused course covering fundamental ...       4 hours.
# 3697  Research and thesis development experience in ...       3 hours.
# 3702  Advanced topics in building and verifying soft...       4 hours.
# 3346         Same as IS 107 and STAT 107. See STAT 107.       4 hours.
# 3583  Layered architectures and the OSI Reference Mo...  3 OR 4 hours.
# 3472  Analysis of algorithms, major paradigms of alg...       4 hours.
# 3389  Continuation of CS 124. More advanced concepts...       3 hours.
# 3451  Basics of system programming, including POSIX ...       4 hours.
# 3712                        Same as IE 534. See IE 534.       4 hours.
# 3606  Linear system solvers, optimization techniques...  3 OR 4 hours.
# 3442  Fundamentals of computer architecture: digital...       4 hours.
# 3344         Same as IS 107 and STAT 107. See STAT 107.       4 hours.
# 3730  Seminar on topics of current interest as annou...  0 TO 4 hours.
# 3650  Design and analysis techniques, approximation ...       4 hours.
# 3686  Student teams work with CS faculty to complete...  1 TO 3 hours.
# 3717                    Same as MATH 580. See MATH 580.       4 hours.
# 3545  Structure of programming languages and their i...  3 OR 4 hours.
# 3662  Finite automata and regular languages; pushdow...  3 OR 4 hours.
# 3335         Same as IS 107 and STAT 107. See STAT 107.       4 hours.
# 3317  Fundamental principles, concepts, and methods ...       3 hours.
# 3558  Protocols, specification techniques, global st...  3 OR 4 hours.
# 3750  Subject offerings of new and developing areas ...  2 TO 4 hours.
# 3685  First part of a project course in computer sci...       3 hours.
# 3578  Topics of networked embedded computing technol...  3 OR 4 hours.
# 3477  Analysis of algorithms, major paradigms of alg...       4 hours.
# 3365         Same as IS 107 and STAT 107. See STAT 107.       4 hours.
# 3324  Computing as an essential tool of academic and...       3 hours.
# 3595  Provides an elementary hands-on introduction t...  3 OR 4 hours.
# 3612  Operating systems security: access control, le...  3 OR 4 hours.
# 3732  Seminar on topics of current interest as annou...  0 TO 4 hours.
# 3531  Concepts, techniques, and systems of data ware...  3 OR 4 hours.
# 3396  Continuation of CS 124. More advanced concepts...       3 hours.
# 3674          Same as CSE 408 and ECE 408. See ECE 408.       4 hours.
# 3753  Subject offerings of new and developing areas ...  2 TO 4 hours.
# 3332         Same as IS 107 and STAT 107. See STAT 107.       4 hours.
# 3304  Fundamental principles, concepts, and methods ...       3 hours.
# 3468  Introduction to probability theory and statist...       3 hours.
# 3767  Subject offerings of new and developing areas ...  2 TO 4 hours.
# 3307  Fundamental principles, concepts, and methods ...       3 hours.
# 3765  Subject offerings of new and developing areas ...  2 TO 4 hours.
# 3390  Continuation of CS 124. More advanced concepts...       3 hours.
# 3380  Basic concepts in computing and fundamental te...       3 hours.
# 3617  Fundamental principles of computer and communi...       4 hours.
# 3445  Introduction to the use of classical approache...       4 hours.
# 3450  Basics of system programming, including POSIX ...       4 hours.
#
#                                            Section Info  \
# 3388                    Prerequisite: CS 124 or CS 125.
# 3705  4 graduate hours. No professional credit. Prer...
# 3368         Same as IS 107 and STAT 107. See STAT 107.
# 3635  4 undergraduate hours. 4 graduate hours. Prere...
# 3697  3 undergraduate hours. No graduate credit. May...
# 3702  4 graduate hours. No professional credit. May ...
# 3346         Same as IS 107 and STAT 107. See STAT 107.
# 3583  Same as ECE 438. 3 undergraduate hours. 3 or 4...
# 3472  Same as ECE 374. Prerequisite: One of CS 173, ...
# 3389                    Prerequisite: CS 124 or CS 125.
# 3451  Credit is not given for both CS 341 and either...
# 3712                        Same as IE 534. See IE 534.
# 3606  Same as CSE 401, ECE 491, and MATH 450. 3 unde...
# 3442  Prerequisite: CS 125 or CS 128; CS 173 or MATH...
# 3344         Same as IS 107 and STAT 107. See STAT 107.
# 3730  Approved for S/U grading only. May be repeated...
# 3650  Same as CSE 414 and MATH 473. 4 undergraduate ...
# 3686  1 to 3 undergraduate hours. No graduate credit...
# 3717                    Same as MATH 580. See MATH 580.
# 3545  3 undergraduate hours. 3 or 4 graduate hours. ...
# 3662  Same as MATH 475. 3 undergraduate hours. 3 or ...
# 3335         Same as IS 107 and STAT 107. See STAT 107.
# 3317  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3558  Same as ECE 428. 3 or 4 undergraduate hours. 3...
# 3750  May be repeated in the same or separate terms ...
# 3685  3 undergraduate hours. No graduate credit. Cre...
# 3578  3 undergraduate hours. 4 graduate hours. May b...
# 3477  Same as ECE 374. Prerequisite: One of CS 173, ...
# 3365         Same as IS 107 and STAT 107. See STAT 107.
# 3324                            Prerequisite: MATH 112.
# 3595  3 undergraduate hours. 4 graduate hours. Prere...
# 3612  Same as ECE 419. 3 undergraduate hours. 3 or 4...
# 3732  Approved for S/U grading only. May be repeated...
# 3531  3 undergraduate hours. 3 or 4 graduate hours. ...
# 3396                    Prerequisite: CS 124 or CS 125.
# 3674          Same as CSE 408 and ECE 408. See ECE 408.
# 3753  May be repeated in the same or separate terms ...
# 3332         Same as IS 107 and STAT 107. See STAT 107.
# 3304  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3468  Same as STAT 361. Credit is not given for both...
# 3767  May be repeated in the same or separate terms ...
# 3307  Prerequisite: One of MATH 220 or MATH 221 or M...
# 3765  May be repeated in the same or separate terms ...
# 3390                    Prerequisite: CS 124 or CS 125.
# 3380  Credit is not given for both CS 124 and CS 125...
# 3617  Same as ECE 422. 4 undergraduate hours. 4 grad...
# 3445  Prerequisite: STAT 207; one of MATH 225, MATH ...
# 3450  Credit is not given for both CS 341 and either...
#
#                       Degree Attributes  ... Section Status  \
# 3388  Quantitative Reasoning II course.  ...              A
# 3705                                NaN  ...              A
# 3368   Quantitative Reasoning I course.  ...              A
# 3635                                NaN  ...              A
# 3697       Advanced Composition course.  ...              A
# 3702                                NaN  ...              A
# 3346   Quantitative Reasoning I course.  ...              A
# 3583                                NaN  ...              A
# 3472                                NaN  ...              A
# 3389  Quantitative Reasoning II course.  ...              A
# 3451                                NaN  ...              A
# 3712                                NaN  ...              A
# 3606                                NaN  ...              A
# 3442                                NaN  ...              A
# 3344   Quantitative Reasoning I course.  ...              A
# 3730                                NaN  ...              A
# 3650                                NaN  ...              A
# 3686                                NaN  ...              A
# 3717                                NaN  ...              A
# 3545                                NaN  ...              A
# 3662                                NaN  ...              A
# 3335   Quantitative Reasoning I course.  ...              A
# 3317  Quantitative Reasoning II course.  ...              A
# 3558                                NaN  ...              A
# 3750                                NaN  ...              A
# 3685                                NaN  ...              A
# 3578                                NaN  ...              A
# 3477                                NaN  ...              A
# 3365   Quantitative Reasoning I course.  ...              A
# 3324   Quantitative Reasoning I course.  ...              A
# 3595                                NaN  ...              A
# 3612                                NaN  ...              A
# 3732                                NaN  ...              A
# 3531                                NaN  ...              A
# 3396  Quantitative Reasoning II course.  ...              A
# 3674                                NaN  ...              A
# 3753                                NaN  ...              A
# 3332   Quantitative Reasoning I course.  ...              A
# 3304  Quantitative Reasoning II course.  ...              A
# 3468                                NaN  ...              A
# 3767                                NaN  ...              A
# 3307  Quantitative Reasoning II course.  ...              A
# 3765                                NaN  ...              A
# 3390  Quantitative Reasoning II course.  ...              A
# 3380   Quantitative Reasoning I course.  ...              A
# 3617                                NaN  ...              A
# 3445                                NaN  ...              A
# 3450                                NaN  ...              A
#
#                Enrollment Status                   Type Type Code Start Time  \
# 3388                      Closed  Laboratory-Discussion       LBD   11:00 AM
# 3705                      Closed     Lecture-Discussion       LCD   02:00 PM
# 3368                      Closed  Laboratory-Discussion       LBD   03:00 PM
# 3635                      Closed  Laboratory-Discussion       LBD   03:30 PM
# 3697                      Closed      Independent Study       IND   ARRANGED
# 3702           Open (Restricted)     Lecture-Discussion       LCD   09:30 AM
# 3346                      Closed  Laboratory-Discussion       LBD   02:00 PM
# 3583                      Closed     Lecture-Discussion       LCD   03:30 PM
# 3472               CrossListOpen  Discussion/Recitation       DIS   09:00 AM
# 3389                      Closed  Laboratory-Discussion       LBD   11:00 AM
# 3451                        Open  Laboratory-Discussion       LBD   11:00 AM
# 3712                      Closed                 Online       ONL   08:00 AM
# 3606  CrossListOpen (Restricted)                 Online       ONL   ARRANGED
# 3442  CrossListOpen (Restricted)         Online Lecture       OLC   09:00 AM
# 3344                      Closed  Laboratory-Discussion       LBD   11:00 AM
# 3730           Open (Restricted)     Lecture-Discussion        S5   ARRANGED
# 3650           Open (Restricted)  Discussion/Recitation       DIS   ARRANGED
# 3686                      Closed      Independent Study       IND   ARRANGED
# 3717  CrossListOpen (Restricted)     Lecture-Discussion       LCD   12:00 PM
# 3545  CrossListOpen (Restricted)     Lecture-Discussion       LCD   12:30 PM
# 3662           Open (Restricted)                 Online       ONL   ARRANGED
# 3335                      Closed  Laboratory-Discussion       LBD   01:00 PM
# 3317                        Open  Laboratory-Discussion       LBD   01:00 PM
# 3558           Open (Restricted)                 Online       ONL   ARRANGED
# 3750                      Closed     Lecture-Discussion       S11   11:00 AM
# 3685           Open (Restricted)     Lecture-Discussion       LCD   04:00 PM
# 3578           Open (Restricted)     Lecture-Discussion       LCD   02:00 PM
# 3477               CrossListOpen  Discussion/Recitation       DIS   02:00 PM
# 3365                      Closed  Laboratory-Discussion       LBD   01:00 PM
# 3324                        Open  Laboratory-Discussion       LBD   09:00 AM
# 3595                      Closed     Lecture-Discussion       LCD   03:30 PM
# 3612  CrossListOpen (Restricted)         Online Lecture       OLC   ARRANGED
# 3732           Open (Restricted)                Lecture       LEC   11:00 AM
# 3531                      Closed     Lecture-Discussion       LCD   11:00 AM
# 3396                        Open  Laboratory-Discussion       LBD   05:00 PM
# 3674                      Closed                Lecture       LEC   09:30 AM
# 3753           Open (Restricted)     Lecture-Discussion       S14   11:00 AM
# 3332                      Closed                Lecture       LEC   11:00 AM
# 3304                      Closed  Laboratory-Discussion       LBD   11:00 AM
# 3468               CrossListOpen  Discussion/Recitation       DIS   03:00 PM
# 3767  CrossListOpen (Restricted)     Lecture-Discussion        S4   12:30 PM
# 3307                        Open  Laboratory-Discussion       LBD   01:00 PM
# 3765                      Closed     Lecture-Discussion        S0   02:00 PM
# 3390                      Closed  Laboratory-Discussion       LBD   12:30 PM
# 3380                        Open  Laboratory-Discussion       LBD   03:00 PM
# 3617               CrossListOpen  Discussion/Recitation       DIS   12:00 PM
# 3445                      Closed         Online Lecture       OLC   ARRANGED
# 3450                      Closed  Laboratory-Discussion       LBD   03:30 PM
#
#       End Time Days of Week   Room                        Building  \
# 3388  12:15 PM            F    218      Siebel Center for Comp Sci
# 3705  03:15 PM           TR   3101        Sidney Lu Mech Engr Bldg
# 3368  03:50 PM            W    313                  Davenport Hall
# 3635  04:50 PM            F   3117              Everitt Laboratory
# 3697       NaN          NaN    NaN                             NaN
# 3702  10:45 AM           TR   2233              Everitt Laboratory
# 3346  02:50 PM            R     29             Psychology Building
# 3583  04:45 PM           MW   1320     Digital Computer Laboratory
# 3472  09:50 AM           WF   2406      Siebel Center for Comp Sci
# 3389  12:15 PM            F    220      Siebel Center for Comp Sci
# 3451  12:20 PM            R    220      Siebel Center for Comp Sci
# 3712  09:20 AM           TR    NaN                             NaN
# 3606       NaN          NaN    NaN                             NaN
# 3442  10:50 AM           TR    NaN                             NaN
# 3344  11:50 AM            R    236                    Wohlers Hall
# 3730       NaN          NaN    ARR      Siebel Center for Comp Sci
# 3650       NaN          NaN    NaN                             NaN
# 3686       NaN          NaN    NaN                             NaN
# 3717  12:50 PM          MWF   3018   Campus Instructional Facility
# 3545  01:45 PM           TR   3031   Campus Instructional Facility
# 3662       NaN          NaN    NaN                             NaN
# 3335  01:50 PM            W    301                Noyes Laboratory
# 3317  02:50 PM            F   2036   Campus Instructional Facility
# 3558       NaN          NaN    NaN                             NaN
# 3750  12:15 PM           TR   1310     Digital Computer Laboratory
# 3685  04:50 PM            W    222      Siebel Center for Comp Sci
# 3578  03:15 PM           TR   1302      Siebel Center for Comp Sci
# 3477  02:50 PM           WF   2406      Siebel Center for Comp Sci
# 3365  01:50 PM            F     21             Psychology Building
# 3324  10:20 AM            T    101                    901 W Oregon
# 3595  04:45 PM           WF   3031   Campus Instructional Facility
# 3612       NaN          NaN    NaN                             NaN
# 3732  11:50 AM            M   1404      Siebel Center for Comp Sci
# 3531  12:15 PM           TR   1404      Siebel Center for Comp Sci
# 3396  06:15 PM            F    222      Siebel Center for Comp Sci
# 3674  10:50 AM           TR   1002  Electrical & Computer Eng Bldg
# 3753  12:15 PM           TR   1043        Sidney Lu Mech Engr Bldg
# 3332  11:50 AM          MWF  THEAT                    Lincoln Hall
# 3304  12:50 PM            T   2036   Campus Instructional Facility
# 3468  03:50 PM            M    218      Siebel Center for Comp Sci
# 3767  01:45 PM           TR   1043        Sidney Lu Mech Engr Bldg
# 3307  02:50 PM            W   1038   Campus Instructional Facility
# 3765  03:15 PM           TR    216      Siebel Center for Comp Sci
# 3390  01:45 PM            F    218      Siebel Center for Comp Sci
# 3380  03:50 PM            T   4025   Campus Instructional Facility
# 3617  12:50 PM            W    220      Siebel Center for Comp Sci
# 3445       NaN          NaN    NaN                             NaN
# 3450  04:50 PM            R    218      Siebel Center for Comp Sci
#
#                             Instructors
# 3388                           Nowak, M
# 3705                         Godfrey, P
# 3368                                NaN
# 3635                          Bailey, B
# 3697                                NaN
# 3702                           Singh, G
# 3346                                NaN
# 3583                  Agarwal, S;Wei, Y
# 3472                       Har-Peled, S
# 3389                           Nowak, M
# 3451                         Angrave, L
# 3712                          Sowers, R
# 3606                       Kloeckner, A
# 3442                          Zilles, C
# 3344                                NaN
# 3730              Kloeckner, A;Olson, L
# 3650                           Sinha, M
# 3686                                NaN
# 3717                         Methuku, A
# 3545                      Misailovic, S
# 3662                     Viswanathan, M
# 3335                                NaN
# 3317                         Beckman, M
# 3558                           Gupta, I
# 3750              Jabbarvand Behrouz, R
# 3685                         Woodley, M
# 3578                     Soltanaghai, E
# 3477                       Har-Peled, S
# 3365                                NaN
# 3324               Fowler, M;Lambert, C
# 3595                           Gupta, S
# 3612                Nicol, D;O'Brien, C
# 3732     Amato, N;Kravets, R;Marinov, D
# 3531                        Banerjee, A
# 3396                           Nowak, M
# 3674                     Kindratenko, V
# 3753                 Granha Jeronimo, F
# 3332  Fagen-Ulmschneider, W;Flanagan, K
# 3304                         Beckman, M
# 3468                             Liu, H
# 3767                 Cobb, C;Sterman, S
# 3307                         Beckman, M
# 3765                            Wang, S
# 3390                           Nowak, M
# 3380                         Challen, G
# 3617                         Borisov, N
# 3445                         Dalpiaz, D
# 3450                         Angrave, L
#
# [48 rows x 27 columns]

# %% [markdown]
# ### ✔️ Checkpoint ✔️
#
# There are no test cases for Part 4 (since everyone has different majors), but go double check your work!  There's just one section left to go! :)

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 5: Growth of the IS major
#
# The IS major is still a new relatively new major here at UIUC. The final puzzle is for you to analyze how much the IS major has grown since 2019.

# %% [markdown]
# ### Puzzle 5.1: Loading the Course Catalog Dataset from 2019
#
# Using the name `df2019` instead of `df`, load the "Fall 2019 Course Catalog Dataset" that can be found at the following URL:
# ```
# https://waf.cs.illinois.edu/discovery/course-catalog-fa19.csv
# ```

# %%
df2019 = pd.read_csv("https://waf.cs.illinois.edu/discovery/course-catalog-fa19.csv")
df2019
# Out:
#       Year  Term YearTerm Subject  Number  \
# 0     2019  Fall  2019-fa     AAS     100
# 1     2019  Fall  2019-fa     AAS     105
# 2     2019  Fall  2019-fa     AAS     120
# 3     2019  Fall  2019-fa     AAS     199
# 4     2019  Fall  2019-fa     AAS     200
# ...    ...   ...      ...     ...     ...
# 8584  2019  Fall  2019-fa    ZULU     202
# 8585  2019  Fall  2019-fa    ZULU     403
# 8586  2019  Fall  2019-fa    ZULU     404
# 8587  2019  Fall  2019-fa    ZULU     405
# 8588  2019  Fall  2019-fa    ZULU     406
#
#                                        Name  \
# 0              Intro Asian American Studies
# 1     Introduction to Arab American Studies
# 2             Intro to Asian Am Pop Culture
# 3                Undergraduate Open Seminar
# 4                      U.S. Race and Empire
# ...                                     ...
# 8584                     Elementary Zulu II
# 8585                    Intermediate Zulu I
# 8586                   Intermediate Zulu II
# 8587                        Advanced Zulu I
# 8588                       Advanced Zulu II
#
#                                             Description   Credit Hours  \
# 0     Interdisciplinary introduction to the basic co...       3 hours.
# 1     Interdisciplinary introduction to the basic co...       3 hours.
# 2     Introductory understanding of the way U.S. pop...       3 hours.
# 3              May be repeated to a maximum of 6 hours.  1 TO 5 hours.
# 4     Invites students to examine histories and narr...       3 hours.
# ...                                                 ...            ...
# 8584  Continuation of ZULU 201 with introduction of ...       5 hours.
# 8585  Survey of more advanced grammar; emphasis on i...       4 hours.
# 8586  Continuation of ZULU 403; emphasis on increasi...       4 hours.
# 8587  Third year Zulu with emphasis on conversationa...       3 hours.
# 8588  Continuation of Zulu 405 with increased emphas...       3 hours.
#
#                                            Section Info  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                      Same as LLS 200.
# ...                                                 ...
# 8584  Same as AFST 252. Participation in the languag...
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
#                                       Degree Attributes
# 0     Social & Beh Sci - Soc Sci, and Cultural Studi...
# 1                Cultural Studies - US Minority course.
# 2                Cultural Studies - US Minority course.
# 3                                                   NaN
# 4     Humanities - Hist & Phil, and Cultural Studies...
# ...                                                 ...
# 8584                                                NaN
# 8585                                                NaN
# 8586                                                NaN
# 8587                                                NaN
# 8588                                                NaN
#
# [8589 rows x 10 columns]

# %% [markdown]
# ### Puzzle 5.2: Data Science Analysis
#
# In the following cells,
# - Select only the rows from the `IS` subject from the `df2019` dataset,
# - Select only the rows from the `IS` subject from the `df` dataset (this contains the Fall 2024 data),
# - Complete the reflection question below (Puzzle 5.3).  Feel free to write more code to answer it.

# %%
df2019 = df2019[ df2019.Subject == "IS"] # select only the rows from the 2019 dataset
df2019
# Out:
#       Year  Term YearTerm Subject  Number  \
# 4843  2019  Fall  2019-fa      IS     107
# 4844  2019  Fall  2019-fa      IS     199
# 4845  2019  Fall  2019-fa      IS     202
# 4846  2019  Fall  2019-fa      IS     310
# 4847  2019  Fall  2019-fa      IS     351
# ...    ...   ...      ...     ...     ...
# 4930  2019  Fall  2019-fa      IS     591
# 4931  2019  Fall  2019-fa      IS     592
# 4932  2019  Fall  2019-fa      IS     593
# 4933  2019  Fall  2019-fa      IS     594
# 4934  2019  Fall  2019-fa      IS     599
#
#                                              Name  \
# 4843                       Data Science Discovery
# 4844                   Undergraduate Open Seminar
# 4845                     Social Aspects Info Tech
# 4846                  Computing in the Humanities
# 4847  The Design of Usable Information Interfaces
# ...                                           ...
# 4930                                    Practicum
# 4931                            Independent Study
# 4932                                  CAS Project
# 4933                Information Sciences Practice
# 4934                              Thesis Research
#
#                                             Description    Credit Hours  \
# 4843          Same as CS 107 and STAT 107. See STAT 107        4 hours.
# 4844       Undergraduate Open Seminar. May be repeated.   1 TO 5 hours.
# 4845       Same as INFO 202 and MACS 202. See INFO 202.        3 hours.
# 4846  Explores use and application of technology to ...        3 hours.
# 4847  Examines issues of Human Computer Interaction ...        3 hours.
# ...                                                 ...             ...
# 4930  Supervised field experience of professional-le...        2 hours.
# 4931  Permits the intermediate or advanced student o...   2 TO 4 hours.
# 4932  Individual study of a problem in library and i...   0 TO 8 hours.
# 4933  Full-time or part-time practice of of any info...        0 hours.
# 4934  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info  \
# 4843          Same as CS 107 and STAT 107. See STAT 107
# 4844                                                NaN
# 4845       Same as INFO 202 and MACS 202. See INFO 202.
# 4846                                                NaN
# 4847                  Prerequisite: Sophomore standing.
# ...                                                 ...
# 4930  2 graduate hours. No professional credit. Appr...
# 4931  2 to 4 graduate hours. No professional credit....
# 4932  0 to 8 graduate hours. No professional credit....
# 4933  0 graduate hours. No professional credit. Appr...
# 4934  0 to 16 graduate hours. No professional credit...
#
#                        Degree Attributes
# 4843    Quantitative Reasoning I course.
# 4844                                 NaN
# 4845  Social & Beh Sci - Soc Sci course.
# 4846                                 NaN
# 4847                                 NaN
# ...                                  ...
# 4930                                 NaN
# 4931                                 NaN
# 4932                                 NaN
# 4933                                 NaN
# 4934                                 NaN
#
# [92 rows x 10 columns]

# %%
df = df[ df.Subject == "IS"] # select only the rows from the IS subject
df
# Out:
#       Year  Term YearTerm Subject  Number  \
# 7003  2024  Fall  2024-fa      IS     100
# 7004  2024  Fall  2024-fa      IS     100
# 7005  2024  Fall  2024-fa      IS     100
# 7006  2024  Fall  2024-fa      IS     100
# 7007  2024  Fall  2024-fa      IS     100
# ...    ...   ...      ...     ...     ...
# 7303  2024  Fall  2024-fa      IS     599
# 7304  2024  Fall  2024-fa      IS     599
# 7305  2024  Fall  2024-fa      IS     599
# 7306  2024  Fall  2024-fa      IS     599
# 7307  2024  Fall  2024-fa      IS     599
#
#                                                   Name  \
# 7003  Exploring the iSchool with a Human-Centered Lens
# 7004  Exploring the iSchool with a Human-Centered Lens
# 7005  Exploring the iSchool with a Human-Centered Lens
# 7006  Exploring the iSchool with a Human-Centered Lens
# 7007  Exploring the iSchool with a Human-Centered Lens
# ...                                                ...
# 7303                                   Thesis Research
# 7304                                   Thesis Research
# 7305                                   Thesis Research
# 7306                                   Thesis Research
# 7307                                   Thesis Research
#
#                                             Description    Credit Hours  \
# 7003  This course introduces students to the School ...        1 hours.
# 7004  This course introduces students to the School ...        1 hours.
# 7005  This course introduces students to the School ...        1 hours.
# 7006  This course introduces students to the School ...        1 hours.
# 7007  This course introduces students to the School ...        1 hours.
# ...                                                 ...             ...
# 7303  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 7304  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 7305  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 7306  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
# 7307  Individual study and research. 0 to 16 graduat...  0 TO 16 hours.
#
#                                            Section Info Degree Attributes  \
# 7003  Prerequisite: Restricted to Majors Only; First...               NaN
# 7004  Prerequisite: Restricted to Majors Only; First...               NaN
# 7005  Prerequisite: Restricted to Majors Only; First...               NaN
# 7006  Prerequisite: Restricted to Majors Only; First...               NaN
# 7007  Prerequisite: Restricted to Majors Only; First...               NaN
# ...                                                 ...               ...
# 7303  0 to 16 graduate hours. No professional credit...               NaN
# 7304  0 to 16 graduate hours. No professional credit...               NaN
# 7305  0 to 16 graduate hours. No professional credit...               NaN
# 7306  0 to 16 graduate hours. No professional credit...               NaN
# 7307  0 to 16 graduate hours. No professional credit...               NaN
#
#       ... Section Status  Enrollment Status                Type Type Code  \
# 7003  ...              A             Closed  Lecture-Discussion       LCD
# 7004  ...              A             Closed  Lecture-Discussion       LCD
# 7005  ...              A             Closed  Lecture-Discussion       LCD
# 7006  ...              A             Closed  Lecture-Discussion       LCD
# 7007  ...              A             Closed  Lecture-Discussion       LCD
# ...   ...            ...                ...                 ...       ...
# 7303  ...              A               Open   Independent Study       IND
# 7304  ...              A               Open   Independent Study       IND
# 7305  ...              A               Open   Independent Study       IND
# 7306  ...              A               Open   Independent Study       IND
# 7307  ...              A               Open   Independent Study       IND
#
#      Start Time  End Time Days of Week Room                        Building  \
# 7003   01:00 PM  01:50 PM            W  126  Grad Sch of Lib & Info Science
# 7004   01:00 PM  01:50 PM            W  126  Grad Sch of Lib & Info Science
# 7005   10:00 AM  10:50 AM            M  126  Grad Sch of Lib & Info Science
# 7006   10:00 AM  10:50 AM            M  126  Grad Sch of Lib & Info Science
# 7007   02:00 PM  02:50 PM            R  126  Grad Sch of Lib & Info Science
# ...         ...       ...          ...  ...                             ...
# 7303   ARRANGED       NaN          NaN  NaN                             NaN
# 7304   ARRANGED       NaN          NaN  NaN                             NaN
# 7305   ARRANGED       NaN          NaN  NaN                             NaN
# 7306   ARRANGED       NaN          NaN  NaN                             NaN
# 7307   ARRANGED       NaN          NaN  NaN                             NaN
#
#              Instructors
# 7003            Kittl, K
# 7004            Kittl, K
# 7005           Lehman, L
# 7006           Lehman, L
# 7007  Kittl, K;Lehman, L
# ...                  ...
# 7303           Torvik, V
# 7304        Underwood, W
# 7305            Huang, Y
# 7306             Wang, Y
# 7307          LeBlanc, Z
#
# [305 rows x 27 columns]

# %%
# Feel free to add more code cells if needed by hovering over the area below the cell and pressing "+ Code"!

# %% [markdown]
# ### Puzzle 5.3: Reflection on the Growth of Information Science
#
# In the follow cell, write **at least one complete sentence explaining what you found** related to the growth of the IS program.  In your answer, **use actual data** (ex: by how much did it grow?)

# %% [markdown]
# *(The growth of the IS program increased from 2019 to 2024 because the number of courses in the IS subject has nearly tripled from 2019 to 2024. In 2019, there were 90 IS courses, while in 2024, that number increased to 303 courses.)*

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission

# %% [markdown]
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
